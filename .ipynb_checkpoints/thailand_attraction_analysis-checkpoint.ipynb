# %% [markdown]
# # Capstone Project
#
# ## Introduction
#
# Thailand, one of the top 10 countries for tourism, but also one of the most congested countires when it comes to traffic. It was rated as the most congested country in 2016 with drivers spending an average of 64 hours stuck in traffic, of which 33% of that time was spent in traffic during peak hours. Another article, published last year, claimed that the authorities place a lot of trust in the traffic officers to manually handle traffic during peak hours, saying that this was probably the best solution at the time. The article also mentions a solution to automate the traffic more, especially during peak hours, using data that could be collected from the different sections of traffic that occur. This project aims to see if some data can be used to gain insightful knowledge on Bangkok's traffic problem. The dataset will be obtained from the Foursquare API calls which will give venues around the Bangkok area. The goal is to be able to cluster and find patterns the venues in Bangkok and seeing if that relates to any of the congested traffic around that area.
#
#
# ## Data
#
# As mentioned in the introduction, the dataset will be obtained from Foursquare using the functionality to obtain the venues around the Bangkok area. The requests should return several venues in the city that could be used to cluster and plot on a map using the `folium` library of Python. If time allows, we will also look at how time plays a role since Foursquare also has the opening times for the venues, which might be related to peak hours of traffic.

# %%
import pandas as pd
import numpy as np
import folium
import requests
from pandas.io.json import json_normalize
from geopy.geocoders import Nominatim
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from matplotlib import colors

# %%
# Credentials for BingMaps
BING_KEY = 'DELETED'

# %%
# Credentials for Foursquare (NEED TO DELETE AFTER)
CLIENT_ID = 'DELETED' # your Foursquare ID
CLIENT_SECRET = 'DELETED' # your Foursquare Secret
VERSION = 'DELETED' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DELETED
# CLIENT_SECRET:DELETED

# %%
# Getting latitude and longitude of Bangkok, Thailand.
target_location = '130 Samsen Soi 2, Bangkok, Thailand'

geolocator = Nominatim(user_agent='bangkok_explorer')
location = geolocator.geocode(target_location)
latitude = location.latitude
longitude = location.longitude
print('Coordinates of Bangkok, Thailand: {}, {}.'.format(latitude, longitude))
# Out:
# Coordinates of Bangkok, Thailand: 13.7627862, 100.499614.

# %%
# Obtaining Traffic data for Bangkok Area
SouthLatitude = 13.3019
WestLongitude = 100.1208
NorthLatitude = 14.1200
EastLongitude = 100.4739
url = 'http://dev.virtualearth.net/REST/v1/Traffic/Incidents/{},{},{},{}?key={}'.format(
    SouthLatitude,
    WestLongitude,
    NorthLatitude,
    EastLongitude,
    BING_KEY
    )
url
# Out:
# 'http://dev.virtualearth.net/REST/v1/Traffic/Incidents/13.3019,100.1208,14.12,100.4739?key=DELETED'

# %%
# Getting top 100 venues in Bangkok
LIMIT = 100
radius = 100000
offset=0
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT,
    offset)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=DELETED&client_secret=DELETED&v=DELETED&ll=13.7627862,100.499614&radius=100000&limit=100&offset=0'

# %%
traffic_results = requests.get(url).json()
traffic_results
# Out:
# {'meta': {'code': 200, 'requestId': '5d258982f19f4400252921bd'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dfb6e666284607895334ba5-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e7931735',
#          'name': 'Jazz Club',
#          'pluralName': 'Jazz Clubs',
#          'primary': True,
#          'shortName': 'Jazz Club'}],
#        'id': '4dfb6e666284607895334ba5',
#        'location': {'address': 'Samsen Rd.',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 88,
#         'formattedAddress': ['Samsen Rd.',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.763043150306821,
#           'lng': 100.49883860848884}],
#         'lat': 13.763043150306821,
#         'lng': 100.49883860848884,
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Adhere the 13th Blues Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fd6b0f0e4b0a25e3aaaa1ff-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4fd6b0f0e4b0a25e3aaaa1ff',
#        'location': {'address': '23',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 714,
#         'formattedAddress': ['23',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.762308252181139,
#           'lng': 100.49302010964642}],
#         'lat': 13.762308252181139,
#         'lng': 100.49302010964642,
#         'neighborhood': 'Chana Songkram',
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Riva Surya Bangkok',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587f9f964a52001aa22e3-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a3e',
#          'name': 'Buddhist Temple',
#          'pluralName': 'Buddhist Temples',
#          'primary': True,
#          'shortName': 'Buddhist Temple'}],
#        'id': '4b0587f9f964a52001aa22e3',
#        'location': {'address': 'Na Phra Lan Rd',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'Maha Rat Rd',
#         'distance': 1442,
#         'formattedAddress': ['Na Phra Lan Rd (Maha Rat Rd)',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.751734643691861,
#           'lng': 100.49265146255493}],
#         'lat': 13.751734643691861,
#         'lng': 100.49265146255493,
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Temple of the Emerald Buddha (วัดพระศรีรัตนศาสดาราม (วัดพระแก้ว))',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e3105c381302aa582e214a7-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a14',
#          'name': 'Palace',
#          'pluralName': 'Palaces',
#          'primary': True,
#          'shortName': 'Palace'}],
#        'id': '4e3105c381302aa582e214a7',
#        'location': {'address': 'The Grand Palace',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 1720,
#         'formattedAddress': ['The Grand Palace',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.750105,
#           'lng': 100.490524}],
#         'lat': 13.750105,
#         'lng': 100.490524,
#         'neighborhood': 'Phra Borom Maha Ratchawang',
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตมหาปราสาท)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b492992f964a520596826e3-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '4b492992f964a520596826e3',
#        'location': {'address': '151/1 Nakhon Chaisi Rd',
#         'cc': 'TH',
#         'city': 'ดุสิต',
#         'country': 'ประเทศไทย',
#         'distance': 2837,
#         'formattedAddress': ['151/1 Nakhon Chaisi Rd',
#          'ดุสิต',
#          'กรุงเทพมหานคร 10300',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.784805121631285,
#           'lng': 100.51283556869235}],
#         'lat': 13.784805121631285,
#         'lng': 100.51283556869235,
#         'postalCode': '10300',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Look Chin Sri Yan (ลูกชิ้นศรีย่าน)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4da03dcfa77d816ea6b81309-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b3c',
#          'name': 'Massage Studio',
#          'pluralName': 'Massage Studios',
#          'primary': True,
#          'shortName': 'Massage Studio'}],
#        'id': '4da03dcfa77d816ea6b81309',
#        'location': {'address': '1/1 Soi Rambuttri',
#         'cc': 'TH',
#         'city': 'Chana Songkhram',
#         'country': 'ประเทศไทย',
#         'distance': 487,
#         'formattedAddress': ['1/1 Soi Rambuttri',
#          'Chana Songkhram',
#          'กรุงเทพมหานคร',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.762362677939603,
#           'lng': 100.4951261002727}],
#         'lat': 13.762362677939603,
#         'lng': 100.4951261002727,
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Massage In Garden',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c80b79374d7b60cabdc6fd8-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_shrine_',
#           'suffix': '.png'},
#          'id': '4eb1d80a4b900d56c88a45ff',
#          'name': 'Shrine',
#          'pluralName': 'Shrines',
#          'primary': True,
#          'shortName': 'Shrine'}],
#        'id': '4c80b79374d7b60cabdc6fd8',
#        'location': {'address': '326 Chao Khamrop Rd',
#         'cc': 'TH',
#         'city': 'ป้อมปราบศัตรูพ่าย',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'at Pohtecktung Foundation',
#         'distance': 2357,
#         'formattedAddress': ['326 Chao Khamrop Rd (at Pohtecktung Foundation)',
#          'ป้อมปราบศัตรูพ่าย',
#          'กรุงเทพมหานคร 10100',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.744577584127368,
#           'lng': 100.51075528166002}],
#         'lat': 13.744577584127368,
#         'lng': 100.51075528166002,
#         'postalCode': '10100',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Tai Hong Kong Shrine (ศาลเจ้าไต้ฮงกง)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55461e9b498e777ecbdb0696-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '55461e9b498e777ecbdb0696',
#        'location': {'address': 'Yodpiman Riverwalk',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'crossStreet': '1st-2nd Fl, #D7-101, #D7-201',
#         'distance': 2474,
#         'formattedAddress': ['Yodpiman Riverwalk (1st-2nd Fl, #D7-101, #D7-201)',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.74093665141006,
#           'lng': 100.49539381826771}],
#         'lat': 13.74093665141006,
#         'lng': 100.49539381826771,
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Starbucks (สตาร์บัคส์)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50568fd6e4b02204c3b9dd0b-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '50568fd6e4b02204c3b9dd0b',
#        'location': {'address': 'Siriraj Piyamaharajkarun Hospital',
#         'cc': 'TH',
#         'city': 'บางกอกน้อย',
#         'country': 'ประเทศไทย',
#         'crossStreet': '2nd Fl',
#         'distance': 1499,
#         'formattedAddress': ['Siriraj Piyamaharajkarun Hospital (2nd Fl)',
#          'บางกอกน้อย',
#          'กรุงเทพมหานคร 10700',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.759788517473279,
#           'lng': 100.48609743058515}],
#         'lat': 13.759788517473279,
#         'lng': 100.48609743058515,
#         'postalCode': '10700',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Starbucks (สตาร์บัคส์)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54e2cdc7498eefaf2e840b85-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/factory_',
#           'suffix': '.png'},
#          'id': '4eb1bea83b7b6f98df247e06',
#          'name': 'Factory',
#          'pluralName': 'Factories',
#          'primary': True,
#          'shortName': 'Factory'}],
#        'id': '54e2cdc7498eefaf2e840b85',
#        'location': {'address': '92/1 Krung Thonburi Road',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 4702,
#         'formattedAddress': ['92/1 Krung Thonburi Road',
#          'พระนคร',
#          'กรุงเทพมหานคร 10600',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.720541638598258,
#           'lng': 100.499507188797}],
#         'lat': 13.720541638598258,
#         'lng': 100.499507188797,
#         'postalCode': '10600',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'ELF925',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b377134f964a520154125e3-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'primary': True,
#          'shortName': 'Bookstore'}],
#        'id': '4b377134f964a520154125e3',
#        'location': {'address': 'Siam Paragon',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': '3rd Fl, #309-314',
#         'distance': 4261,
#         'formattedAddress': ['Siam Paragon (3rd Fl, #309-314)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.745838803758621,
#           'lng': 100.5349506607895}],
#         'lat': 13.745838803758621,
#         'lng': 100.5349506607895,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Books Kinokuniya (คิโนะคูนิยะ)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-509a31b8e4b07ae84f975465-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '509a31b8e4b07ae84f975465',
#        'location': {'address': 'Bang Khun Non Rd',
#         'cc': 'TH',
#         'city': 'บางกอกน้อย',
#         'country': 'ประเทศไทย',
#         'distance': 3531,
#         'formattedAddress': ['Bang Khun Non Rd',
#          'บางกอกน้อย',
#          'กรุงเทพมหานคร 10700',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.77226574904896,
#           'lng': 100.4684410214013}],
#         'lat': 13.77226574904896,
#         'lng': 100.4684410214013,
#         'postalCode': '10700',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'สวนเฉลิมพระเกียรติ ๘๐ พรรษา พระบาทสมเด็จพระเจ้าอยู่หัว',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c16c642955976b0e31ba5f6-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d12f951735',
#          'name': 'Resort',
#          'pluralName': 'Resorts',
#          'primary': True,
#          'shortName': 'Resort'}],
#        'id': '4c16c642955976b0e31ba5f6',
#        'location': {'address': '48 Oriental Ave',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 4598,
#         'formattedAddress': ['48 Oriental Ave',
#          'พระนคร',
#          'กรุงเทพมหานคร 10500',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.7239926,
#           'lng': 100.5142411}],
#         'lat': 13.7239926,
#         'lng': 100.5142411,
#         'postalCode': '10500',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Mandarin Oriental, Bangkok',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-500532c6e4b0f0192ae31b47-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '500532c6e4b0f0192ae31b47',
#        'location': {'address': '3/2 Khao Rd',
#         'cc': 'TH',
#         'city': 'ดุสิต',
#         'country': 'ประเทศไทย',
#         'distance': 2197,
#         'formattedAddress': ['3/2 Khao Rd',
#          'ดุสิต',
#          'กรุงเทพมหานคร 10300',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.781878757576028,
#           'lng': 100.50477541525963}],
#         'lat': 13.781878757576028,
#         'lng': 100.50477541525963,
#         'postalCode': '10300',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'The Siam',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bfde0aef7c82d7fa0e98e04-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4bfde0aef7c82d7fa0e98e04',
#        'location': {'address': 'Royal Bangkok Sports Club',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'Henri Dunant Rd',
#         'distance': 4709,
#         'formattedAddress': ['Royal Bangkok Sports Club (Henri Dunant Rd)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.739676389224387,
#           'lng': 100.53609735924066}],
#         'lat': 13.739676389224387,
#         'lng': 100.53609735924066,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'RBSC Fitness Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54a15cd5498e598692a22594-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '54a15cd5498e598692a22594',
#        'location': {'address': '42 Soi Ari 5',
#         'cc': 'TH',
#         'city': 'พญาไท',
#         'country': 'ประเทศไทย',
#         'distance': 4609,
#         'formattedAddress': ['42 Soi Ari 5',
#          'พญาไท',
#          'กรุงเทพมหานคร 10400',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.779563343964318,
#           'lng': 100.538590870639}],
#         'lat': 13.779563343964318,
#         'lng': 100.538590870639,
#         'postalCode': '10400',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Hanazen (ฮานะเซน)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dfb0210d164f73de7cbbcd3-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b3c',
#          'name': 'Massage Studio',
#          'pluralName': 'Massage Studios',
#          'primary': True,
#          'shortName': 'Massage Studio'}],
#        'id': '4dfb0210d164f73de7cbbcd3',
#        'location': {'address': '2 SanamChai Rd, Pranakhon',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'Maharaj Rd, Pranakhon',
#         'distance': 1898,
#         'formattedAddress': ['2 SanamChai Rd, Pranakhon (Maharaj Rd, Pranakhon)',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.746596,
#           'lng': 100.4941}],
#         'lat': 13.746596,
#         'lng': 100.4941,
#         'neighborhood': 'Phra Borom Maha Ratchawang',
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Wat Pho Thai Traditional Medical and Massage School',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5131c9a5e4b09cc35d6934f3-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'id': '56aa371be4b08b9a8d573520',
#          'name': 'Tour Provider',
#          'pluralName': 'Tour Providers',
#          'primary': True,
#          'shortName': 'Tour Provider'}],
#        'id': '5131c9a5e4b09cc35d6934f3',
#        'location': {'address': '23 Charoen Krung Road, Soi 24',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 3903,
#         'formattedAddress': ['23 Charoen Krung Road, Soi 24',
#          'พระนคร',
#          'กรุงเทพมหานคร 10100',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.73055252984124,
#           'lng': 100.5138346153356}],
#         'lat': 13.73055252984124,
#         'lng': 100.5138346153356,
#         'postalCode': '10100',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Co van Kessel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-532c0ca5498e9f9699c35813-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'primary': True,
#          'shortName': 'Historic Site'}],
#        'id': '532c0ca5498e9f9699c35813',
#        'location': {'address': 'Wat Arun Rajwararam',
#         'cc': 'TH',
#         'city': 'บางกอกใหญ่',
#         'country': 'ประเทศไทย',
#         'distance': 2418,
#         'formattedAddress': ['Wat Arun Rajwararam',
#          'บางกอกใหญ่',
#          'กรุงเทพมหานคร 10600',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.743696,
#           'lng': 100.48893}],
#         'lat': 13.743696,
#         'lng': 100.48893,
#         'neighborhood': 'Wat Arun',
#         'postalCode': '10600',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Wat Arun Prang (พระปรางค์วัดอรุณฯ)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-592fd22df5e9d71a33527d14-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'primary': True,
#          'shortName': 'Thai'}],
#        'id': '592fd22df5e9d71a33527d14',
#        'location': {'address': '392/25-26 Maha Rat Rd',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 2242,
#         'formattedAddress': ['392/25-26 Maha Rat Rd',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.744162008588983,
#           'lng': 100.4916997083078}],
#         'lat': 13.744162008588983,
#         'lng': 100.4916997083078,
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Supanniga Eating Room x Roots Coffee (ห้องทานข้าวสุพรรณิการ์ บาย คุณยาย x รูทส์ คอฟฟี่)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bee67afd355a5933cdb0a60-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'primary': True,
#          'shortName': 'Spa'}],
#        'id': '4bee67afd355a5933cdb0a60',
#        'location': {'address': '156 Rambuttri Rd',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 376,
#         'formattedAddress': ['156 Rambuttri Rd',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.759521804989552,
#           'lng': 100.49869412600889}],
#         'lat': 13.759521804989552,
#         'lng': 100.49869412600889,
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Pai Spa (ปัยย์สปา บ้านรามบุตรี)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d7f5c0a4219a1cdedaa72d3-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'id': '56aa371be4b08b9a8d573502',
#          'name': 'Som Tum Restaurant',
#          'pluralName': 'Som Tum Restaurants',
#          'primary': True,
#          'shortName': 'Som Tum'}],
#        'id': '4d7f5c0a4219a1cdedaa72d3',
#        'location': {'address': 'Pin Ngeun Pin Tong Plaza',
#         'cc': 'TH',
#         'city': 'บางพลัด',
#         'country': 'ประเทศไทย',
#         'distance': 3024,
#         'formattedAddress': ['Pin Ngeun Pin Tong Plaza',
#          'บางพลัด',
#          'กรุงเทพมหานคร 10700',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.779375097670426,
#           'lng': 100.47746451036217}],
#         'lat': 13.779375097670426,
#         'lng': 100.47746451036217,
#         'postalCode': '10700',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Ta Bun Tum (ตะบันตำ)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b41cdfbf964a52009c925e3-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'primary': True,
#          'shortName': 'Supermarket'}],
#        'id': '4b41cdfbf964a52009c925e3',
#        'location': {'address': 'Siam Paragon',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'G Fl',
#         'distance': 4197,
#         'formattedAddress': ['Siam Paragon (G Fl)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.746354153183773,
#           'lng': 100.53455026968452}],
#         'lat': 13.746354153183773,
#         'lng': 100.53455026968452,
#         'neighborhood': 'Pathum Wan',
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Gourmet Market (กูร์เมต์ มาร์เก็ต)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51a257a5498e7f0ebdea7108-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'primary': True,
#          'shortName': 'Hostel'}],
#        'id': '51a257a5498e7f0ebdea7108',
#        'location': {'address': '55/39 Soi Kolit',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 3761,
#         'formattedAddress': ['55/39 Soi Kolit',
#          'พญาไท',
#          'กรุงเทพมหานคร 10400',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.755930720874755,
#           'lng': 100.53367786842162}],
#         'lat': 13.755930720874755,
#         'lng': 100.53367786842162,
#         'postalCode': '10400',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'In a Box Hostel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58edbb2214f8f4278e385b8f-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '58edbb2214f8f4278e385b8f',
#        'location': {'address': 'Siam Center',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': '2nd Fl',
#         'distance': 3940,
#         'formattedAddress': ['Siam Center (2nd Fl)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.746508592388071,
#           'lng': 100.53197353879868}],
#         'lat': 13.746508592388071,
#         'lng': 100.53197353879868,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Tonkatsu Wako (หมูทอด วาโก)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4baaeda4f964a520428e3ae3-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'primary': True,
#          'shortName': 'Historic Site'}],
#        'id': '4baaeda4f964a520428e3ae3',
#        'location': {'address': '315 Ratchawithi Rd',
#         'cc': 'TH',
#         'city': 'ราชเทวี',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'at Phramongkutklao Hospital',
#         'distance': 3637,
#         'formattedAddress': ['315 Ratchawithi Rd (at Phramongkutklao Hospital)',
#          'ราชเทวี',
#          'กรุงเทพมหานคร 10400',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.768418538434307,
#           'lng': 100.5327558517456}],
#         'lat': 13.768418538434307,
#         'lng': 100.5327558517456,
#         'postalCode': '10400',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Phya Thai Palace (พระราชวังพญาไท)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54a8c73f498e9be466164ab5-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'primary': True,
#          'shortName': 'Hostel'}],
#        'id': '54a8c73f498e9be466164ab5',
#        'location': {'address': '51 Soi Phahon Yothin 5',
#         'cc': 'TH',
#         'city': 'พญาไท',
#         'country': 'ประเทศไทย',
#         'distance': 4795,
#         'formattedAddress': ['51 Soi Phahon Yothin 5',
#          'พญาไท',
#          'กรุงเทพมหานคร 10400',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.776261438263981,
#           'lng': 100.54174442102409}],
#         'lat': 13.776261438263981,
#         'lng': 100.54174442102409,
#         'postalCode': '10400',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'The Yard (บ้านญาติ โฮสเทล)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c2adbf3ae6820a1e9011743-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '4c2adbf3ae6820a1e9011743',
#        'location': {'address': '1125-1127 Rama IV Rd',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'distance': 4104,
#         'formattedAddress': ['1125-1127 Rama IV Rd',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.734807,
#           'lng': 100.52434}],
#         'lat': 13.734807,
#         'lng': 100.52434,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Rod Dee Det (รสดีเด็ด)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5018bda2e4b08d7ed9d92efa-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '5018bda2e4b08d7ed9d92efa',
#        'location': {'address': 'Itsaraphap Rd.',
#         'cc': 'TH',
#         'city': 'บางกอกน้อย',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'at Nantha Uthayan Samosorn',
#         'distance': 2597,
#         'formattedAddress': ['Itsaraphap Rd. (at Nantha Uthayan Samosorn)',
#          'บางกอกน้อย',
#          'กรุงเทพมหานคร 10700',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.751463535278244,
#           'lng': 100.47860499448731}],
#         'lat': 13.751463535278244,
#         'lng': 100.47860499448731,
#         'postalCode': '10700',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Mont Nom Sod (มนต์นมสด)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c20b858d8b5b7132385dbec-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4c20b858d8b5b7132385dbec',
#        'location': {'address': '991/9 Rama I Rd',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'distance': 4161,
#         'formattedAddress': ['991/9 Rama I Rd',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.748260167423403,
#           'lng': 100.53507371971705}],
#         'lat': 13.748260167423403,
#         'lng': 100.53507371971705,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Siam Kempinski Hotel Bangkok',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c4b9a6e9c8d2d7f44e2286b-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '4c4b9a6e9c8d2d7f44e2286b',
#        'location': {'address': 'Phraeng Phuthon',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 1246,
#         'formattedAddress': ['Phraeng Phuthon',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.751772178605945,
#           'lng': 100.49752735845928}],
#         'lat': 13.751772178605945,
#         'lng': 100.49752735845928,
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Nattaporn Ice cream (นัฐพร ไอศครีมกะทิสดแท้)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587fdf964a52034ab22e3-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'primary': True,
#          'shortName': 'Mall'}],
#        'id': '4b0587fdf964a52034ab22e3',
#        'location': {'address': '991 Rama I Rd',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'distance': 4202,
#         'formattedAddress': ['991 Rama I Rd',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.746979229315318,
#           'lng': 100.53491234779358}],
#         'lat': 13.746979229315318,
#         'lng': 100.53491234779358,
#         'neighborhood': 'ปทุมวัน',
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Siam Paragon (สยามพารากอน)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54114fb1498e6999c97d5e1a-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'primary': True,
#          'shortName': 'Desserts'}],
#        'id': '54114fb1498e6999c97d5e1a',
#        'location': {'address': 'Siam Square One',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'crossStreet': '1st Fl.',
#         'distance': 4231,
#         'formattedAddress': ['Siam Square One (1st Fl.)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.744226759320874,
#           'lng': 100.53376708453843}],
#         'lat': 13.744226759320874,
#         'lng': 100.53376708453843,
#         'neighborhood': 'Pathum Wan',
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'After You (อาฟเตอร์ ยู)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587f8f964a5208fa922e3-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'primary': True,
#          'shortName': 'Hotel Bar'}],
#        'id': '4b0587f8f964a5208fa922e3',
#        'location': {'address': '48 Oriental Avenue',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 4571,
#         'formattedAddress': ['48 Oriental Avenue',
#          'พระนคร',
#          'กรุงเทพมหานคร 10500',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.7241436,
#           'lng': 100.5139267}],
#         'lat': 13.7241436,
#         'lng': 100.5139267,
#         'postalCode': '10500',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'The Bamboo Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587fcf964a52002ab22e3-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'primary': True,
#          'shortName': 'Mall'}],
#        'id': '4b0587fcf964a52002ab22e3',
#        'location': {'address': '999/9 Rama I Rd',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'Ratchadamri Rd',
#         'distance': 4660,
#         'formattedAddress': ['999/9 Rama I Rd (Ratchadamri Rd)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'lat': 13.74664580692352,
#         'lng': 100.53938158613465,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'centralwOrld (เซ็นทรัลเวิลด์)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0d131ff964a520a04323e3-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'primary': True,
#          'shortName': 'Cineplex'}],
#        'id': '4b0d131ff964a520a04323e3',
#        'location': {'address': 'Siam Paragon',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': '5th-6th Fl',
#         'distance': 4270,
#         'formattedAddress': ['Siam Paragon (5th-6th Fl)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.745879026615864,
#           'lng': 100.53506244588786}],
#         'lat': 13.745879026615864,
#         'lng': 100.53506244588786,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Paragon Cineplex (พารากอน ซีนีเพล็กซ์)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d1c70a47e10a35d342eff82-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'primary': True,
#          'shortName': 'Desserts'}],
#        'id': '4d1c70a47e10a35d342eff82',
#        'location': {'address': 'Siam Paragon',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'G Fl.',
#         'distance': 4143,
#         'formattedAddress': ['Siam Paragon (G Fl.)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.746760556467747,
#           'lng': 100.53420180451687}],
#         'lat': 13.746760556467747,
#         'lng': 100.53420180451687,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'After You (อาฟเตอร์ ยู)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c11c79ba9420f47e66e7d51-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'primary': True,
#          'shortName': 'Thai'}],
#        'id': '4c11c79ba9420f47e66e7d51',
#        'location': {'address': 'สามย่าน',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'distance': 4396,
#         'formattedAddress': ['สามย่าน',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.734144100977481,
#           'lng': 100.52760866390587}],
#         'lat': 13.734144100977481,
#         'lng': 100.52760866390587,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'สุกี้สามย่าน',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587f6f964a52030a922e3-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4b0587f6f964a52030a922e3',
#        'location': {'address': '333 Charoen Nakhon Rd',
#         'cc': 'TH',
#         'city': 'คลองสาน',
#         'country': 'ประเทศไทย',
#         'distance': 4600,
#         'formattedAddress': ['333 Charoen Nakhon Rd',
#          'คลองสาน',
#          'กรุงเทพมหานคร 10600',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.723022223223593,
#           'lng': 100.51121771335602}],
#         'lat': 13.723022223223593,
#         'lng': 100.51121771335602,
# ...
#          'เขตคลองเตย',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.745626,
#           'lng': 100.556366}],
#         'lat': 13.745626,
#         'lng': 100.556366,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Charcoal Tandoor Grill & Mixology',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94394468'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55191569498e18feb9544baa-88',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'primary': True,
#          'shortName': 'Mall'}],
#        'id': '55191569498e18feb9544baa',
#        'location': {'address': '693,695 Sukhumvit Rd',
#         'cc': 'TH',
#         'city': 'คลองเตย',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'btwn Soi 35 & 37',
#         'distance': 8335,
#         'formattedAddress': ['693,695 Sukhumvit Rd (btwn Soi 35 & 37)',
#          'คลองเตย',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.73137055274451,
#           'lng': 100.56958794593811}],
#         'lat': 13.73137055274451,
#         'lng': 100.56958794593811,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'EmQuartier (เอ็มควอเทียร์)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50b7701ce4b0c9f8dc6863c4-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '50b7701ce4b0c9f8dc6863c4',
#        'location': {'address': '808/13 Thararom 2',
#         'cc': 'TH',
#         'city': 'วัฒนา',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'Sukhumvit 55',
#         'distance': 9618,
#         'formattedAddress': ['808/13 Thararom 2 (Sukhumvit 55)',
#          'วัฒนา',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.73677,
#           'lng': 100.58444}],
#         'lat': 13.73677,
#         'lng': 100.58444,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': "Kenji's Lab",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54addec5498e0da4bfe14445-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_',
#           'suffix': '.png'},
#          'id': '53e510b7498ebcb1801b55d4',
#          'name': 'Night Market',
#          'pluralName': 'Night Markets',
#          'primary': True,
#          'shortName': 'Night Market'}],
#        'id': '54addec5498e0da4bfe14445',
#        'location': {'address': 'Ratchadaphisek Rd',
#         'cc': 'TH',
#         'city': 'Din Daeng',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'behind Esplanade Ratchadaphisek',
#         'distance': 7496,
#         'formattedAddress': ['Ratchadaphisek Rd (behind Esplanade Ratchadaphisek)',
#          'Din Daeng',
#          'กรุงเทพมหานคร 10400',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.766791088179174,
#           'lng': 100.56882721500156}],
#         'lat': 13.766791088179174,
#         'lng': 100.56882721500156,
#         'postalCode': '10400',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Train Night Market Ratchada (ตลาดนัดรถไฟ รัชดา)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ba1c25ff964a52033cb37e3-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'id': '4ba1c25ff964a52033cb37e3',
#        'location': {'address': '293 Ekkamai Rd',
#         'cc': 'TH',
#         'city': 'วัฒนา',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'at Soi 15',
#         'distance': 10025,
#         'formattedAddress': ['293 Ekkamai Rd (at Soi 15)',
#          'วัฒนา',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.734906083787719,
#           'lng': 100.58777773910936}],
#         'lat': 13.734906083787719,
#         'lng': 100.58777773910936,
#         'neighborhood': 'Vadhana',
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Arunwan (อรุณวรรณ)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bdb6cf363c5c9b66cf22768-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4bdb6cf363c5c9b66cf22768',
#        'location': {'address': 'Rama III Rd',
#         'cc': 'TH',
#         'city': 'บางคอแหลม',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'near Rama IX Bridge',
#         'distance': 8818,
#         'formattedAddress': ['Rama III Rd (near Rama IX Bridge)',
#          'บางคอแหลม',
#          'กรุงเทพมหานคร 10120',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.685723688067712,
#           'lng': 100.51852425355858}],
#         'lat': 13.685723688067712,
#         'lng': 100.51852425355858,
#         'postalCode': '10120',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Chaaloem Phrakiat Park (สวนสาธารณะเฉลิมพระเกียรติ 6 รอบ)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52e4d506498ea9ece63bb0eb-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '52e4d506498ea9ece63bb0eb',
#        'location': {'address': 'K-Village',
#         'cc': 'TH',
#         'city': 'คลองเตย',
#         'country': 'ประเทศไทย',
#         'crossStreet': '93, 95 Sukhumvit 26',
#         'distance': 8860,
#         'formattedAddress': ['K-Village (93, 95 Sukhumvit 26)',
#          'คลองเตย',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.721022985405543,
#           'lng': 100.56937366609165}],
#         'lat': 13.721022985405543,
#         'lng': 100.56937366609165,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'manycups',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '78850654'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b989229f964a520474735e3-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'primary': True,
#          'shortName': 'Sushi'}],
#        'id': '4b989229f964a520474735e3',
#        'location': {'address': '5 Soi Sukhumvit 31',
#         'cc': 'TH',
#         'city': 'วัฒนา',
#         'country': 'ประเทศไทย',
#         'distance': 7877,
#         'formattedAddress': ['5 Soi Sukhumvit 31',
#          'วัฒนา',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.734558407918616,
#           'lng': 100.56641749207378}],
#         'lat': 13.734558407918616,
#         'lng': 100.56641749207378,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'ISAO (อิซาโอะ)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b6173aaf964a5200c142ae3-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'primary': True,
#          'shortName': 'Spa'}],
#        'id': '4b6173aaf964a5200c142ae3',
#        'location': {'address': '64 Sukhumvit 31',
#         'cc': 'TH',
#         'city': 'วัฒนา',
#         'country': 'ประเทศไทย',
#         'distance': 7810,
#         'formattedAddress': ['64 Sukhumvit 31',
#          'วัฒนา',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.740832683338237,
#           'lng': 100.56822486330783}],
#         'lat': 13.740832683338237,
#         'lng': 100.56822486330783,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'The Oasis Spa',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e61e71752b1260c12e36559-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '4e61e71752b1260c12e36559',
#        'location': {'address': '684 Rama III Rd.',
#         'cc': 'TH',
#         'city': 'ยานนาวา',
#         'country': 'ประเทศไทย',
#         'distance': 9921,
#         'formattedAddress': ['684 Rama III Rd.',
#          'ยานนาวา',
#          'กรุงเทพมหานคร 10120',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.677992590801482,
#           'lng': 100.52788741578124}],
#         'lat': 13.677992590801482,
#         'lng': 100.52788741578124,
#         'neighborhood': 'Yan Nawa',
#         'postalCode': '10120',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'ก๋วยเตี๋ยวเนื้อตุ๋นท่าน้ำสาธุฯ',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56d5928a498ea5253b41542c-97',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10d941735',
#          'name': 'German Restaurant',
#          'pluralName': 'German Restaurants',
#          'primary': True,
#          'shortName': 'German'}],
#        'id': '56d5928a498ea5253b41542c',
#        'location': {'address': '10 Soi Yen Akat 3',
#         'cc': 'TH',
#         'city': 'ยานนาวา',
#         'country': 'ประเทศไทย',
#         'distance': 7634,
#         'formattedAddress': ['10 Soi Yen Akat 3',
#          'ยานนาวา',
#          'กรุงเทพมหานคร 10120',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.710749332945863,
#           'lng': 100.54560710752581}],
#         'lat': 13.710749332945863,
#         'lng': 100.54560710752581,
#         'postalCode': '10120',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Sühring',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bbead8d006dc9b6519efb3f-98',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '4bbead8d006dc9b6519efb3f',
#        'location': {'address': '3 Soi Sun Wichai 7',
#         'cc': 'TH',
#         'city': 'ห้วยขวาง',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'next to Bangkok Hospital',
#         'distance': 9214,
#         'formattedAddress': ['3 Soi Sun Wichai 7 (next to Bangkok Hospital)',
#          'ห้วยขวาง',
#          'กรุงเทพมหานคร 10320',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.747697289941192,
#           'lng': 100.58340351100968}],
#         'lat': 13.747697289941192,
#         'lng': 100.58340351100968,
#         'neighborhood': 'Huai Khwang',
#         'postalCode': '10320',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Lookshin Anamai (ลูกชิ้น อนามัย)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51c43ab2498e7b8d3ad9fe2c-99',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '51c43ab2498e7b8d3ad9fe2c',
#        'location': {'address': '14 Sukhumvit 61',
#         'cc': 'TH',
#         'city': 'วัฒนา',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'Sukhumvit',
#         'distance': 10087,
#         'formattedAddress': ['14 Sukhumvit 61 (Sukhumvit)',
#          'วัฒนา',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.722948072234914,
#           'lng': 100.58340138893769}],
#         'lat': 13.722948072234914,
#         'lng': 100.58340138893769,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Teppen (เท้ปเป้น)',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Bangkok',
#   'headerLocation': 'Bangkok',
#   'headerLocationGranularity': 'city',
#   'suggestedBounds': {'ne': {'lat': 14.662787100000902,
#     'lng': 101.42448856591272},
#    'sw': {'lat': 12.8627852999991, 'lng': 99.57473943408726}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 193}}

# %% [markdown]
# It seems that the Bing Map Data is sparse for Bangkok, Thailand area for traffic incidents! So we are going to need to find another route.

# %%
# Calling the Foursquare API
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d258983dbde1100250c8786'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dfb6e666284607895334ba5-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e7931735',
#          'name': 'Jazz Club',
#          'pluralName': 'Jazz Clubs',
#          'primary': True,
#          'shortName': 'Jazz Club'}],
#        'id': '4dfb6e666284607895334ba5',
#        'location': {'address': 'Samsen Rd.',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 88,
#         'formattedAddress': ['Samsen Rd.',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.763043150306821,
#           'lng': 100.49883860848884}],
#         'lat': 13.763043150306821,
#         'lng': 100.49883860848884,
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Adhere the 13th Blues Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fd6b0f0e4b0a25e3aaaa1ff-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4fd6b0f0e4b0a25e3aaaa1ff',
#        'location': {'address': '23',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 714,
#         'formattedAddress': ['23',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.762308252181139,
#           'lng': 100.49302010964642}],
#         'lat': 13.762308252181139,
#         'lng': 100.49302010964642,
#         'neighborhood': 'Chana Songkram',
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Riva Surya Bangkok',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587f9f964a52001aa22e3-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a3e',
#          'name': 'Buddhist Temple',
#          'pluralName': 'Buddhist Temples',
#          'primary': True,
#          'shortName': 'Buddhist Temple'}],
#        'id': '4b0587f9f964a52001aa22e3',
#        'location': {'address': 'Na Phra Lan Rd',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'Maha Rat Rd',
#         'distance': 1442,
#         'formattedAddress': ['Na Phra Lan Rd (Maha Rat Rd)',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.751734643691861,
#           'lng': 100.49265146255493}],
#         'lat': 13.751734643691861,
#         'lng': 100.49265146255493,
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Temple of the Emerald Buddha (วัดพระศรีรัตนศาสดาราม (วัดพระแก้ว))',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e3105c381302aa582e214a7-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a14',
#          'name': 'Palace',
#          'pluralName': 'Palaces',
#          'primary': True,
#          'shortName': 'Palace'}],
#        'id': '4e3105c381302aa582e214a7',
#        'location': {'address': 'The Grand Palace',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 1720,
#         'formattedAddress': ['The Grand Palace',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.750105,
#           'lng': 100.490524}],
#         'lat': 13.750105,
#         'lng': 100.490524,
#         'neighborhood': 'Phra Borom Maha Ratchawang',
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตมหาปราสาท)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b492992f964a520596826e3-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '4b492992f964a520596826e3',
#        'location': {'address': '151/1 Nakhon Chaisi Rd',
#         'cc': 'TH',
#         'city': 'ดุสิต',
#         'country': 'ประเทศไทย',
#         'distance': 2837,
#         'formattedAddress': ['151/1 Nakhon Chaisi Rd',
#          'ดุสิต',
#          'กรุงเทพมหานคร 10300',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.784805121631285,
#           'lng': 100.51283556869235}],
#         'lat': 13.784805121631285,
#         'lng': 100.51283556869235,
#         'postalCode': '10300',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Look Chin Sri Yan (ลูกชิ้นศรีย่าน)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4da03dcfa77d816ea6b81309-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b3c',
#          'name': 'Massage Studio',
#          'pluralName': 'Massage Studios',
#          'primary': True,
#          'shortName': 'Massage Studio'}],
#        'id': '4da03dcfa77d816ea6b81309',
#        'location': {'address': '1/1 Soi Rambuttri',
#         'cc': 'TH',
#         'city': 'Chana Songkhram',
#         'country': 'ประเทศไทย',
#         'distance': 487,
#         'formattedAddress': ['1/1 Soi Rambuttri',
#          'Chana Songkhram',
#          'กรุงเทพมหานคร',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.762362677939603,
#           'lng': 100.4951261002727}],
#         'lat': 13.762362677939603,
#         'lng': 100.4951261002727,
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Massage In Garden',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c80b79374d7b60cabdc6fd8-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_shrine_',
#           'suffix': '.png'},
#          'id': '4eb1d80a4b900d56c88a45ff',
#          'name': 'Shrine',
#          'pluralName': 'Shrines',
#          'primary': True,
#          'shortName': 'Shrine'}],
#        'id': '4c80b79374d7b60cabdc6fd8',
#        'location': {'address': '326 Chao Khamrop Rd',
#         'cc': 'TH',
#         'city': 'ป้อมปราบศัตรูพ่าย',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'at Pohtecktung Foundation',
#         'distance': 2357,
#         'formattedAddress': ['326 Chao Khamrop Rd (at Pohtecktung Foundation)',
#          'ป้อมปราบศัตรูพ่าย',
#          'กรุงเทพมหานคร 10100',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.744577584127368,
#           'lng': 100.51075528166002}],
#         'lat': 13.744577584127368,
#         'lng': 100.51075528166002,
#         'postalCode': '10100',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Tai Hong Kong Shrine (ศาลเจ้าไต้ฮงกง)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55461e9b498e777ecbdb0696-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '55461e9b498e777ecbdb0696',
#        'location': {'address': 'Yodpiman Riverwalk',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'crossStreet': '1st-2nd Fl, #D7-101, #D7-201',
#         'distance': 2474,
#         'formattedAddress': ['Yodpiman Riverwalk (1st-2nd Fl, #D7-101, #D7-201)',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.74093665141006,
#           'lng': 100.49539381826771}],
#         'lat': 13.74093665141006,
#         'lng': 100.49539381826771,
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Starbucks (สตาร์บัคส์)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50568fd6e4b02204c3b9dd0b-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '50568fd6e4b02204c3b9dd0b',
#        'location': {'address': 'Siriraj Piyamaharajkarun Hospital',
#         'cc': 'TH',
#         'city': 'บางกอกน้อย',
#         'country': 'ประเทศไทย',
#         'crossStreet': '2nd Fl',
#         'distance': 1499,
#         'formattedAddress': ['Siriraj Piyamaharajkarun Hospital (2nd Fl)',
#          'บางกอกน้อย',
#          'กรุงเทพมหานคร 10700',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.759788517473279,
#           'lng': 100.48609743058515}],
#         'lat': 13.759788517473279,
#         'lng': 100.48609743058515,
#         'postalCode': '10700',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Starbucks (สตาร์บัคส์)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54e2cdc7498eefaf2e840b85-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/factory_',
#           'suffix': '.png'},
#          'id': '4eb1bea83b7b6f98df247e06',
#          'name': 'Factory',
#          'pluralName': 'Factories',
#          'primary': True,
#          'shortName': 'Factory'}],
#        'id': '54e2cdc7498eefaf2e840b85',
#        'location': {'address': '92/1 Krung Thonburi Road',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 4702,
#         'formattedAddress': ['92/1 Krung Thonburi Road',
#          'พระนคร',
#          'กรุงเทพมหานคร 10600',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.720541638598258,
#           'lng': 100.499507188797}],
#         'lat': 13.720541638598258,
#         'lng': 100.499507188797,
#         'postalCode': '10600',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'ELF925',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b377134f964a520154125e3-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'primary': True,
#          'shortName': 'Bookstore'}],
#        'id': '4b377134f964a520154125e3',
#        'location': {'address': 'Siam Paragon',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': '3rd Fl, #309-314',
#         'distance': 4261,
#         'formattedAddress': ['Siam Paragon (3rd Fl, #309-314)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.745838803758621,
#           'lng': 100.5349506607895}],
#         'lat': 13.745838803758621,
#         'lng': 100.5349506607895,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Books Kinokuniya (คิโนะคูนิยะ)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-509a31b8e4b07ae84f975465-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '509a31b8e4b07ae84f975465',
#        'location': {'address': 'Bang Khun Non Rd',
#         'cc': 'TH',
#         'city': 'บางกอกน้อย',
#         'country': 'ประเทศไทย',
#         'distance': 3531,
#         'formattedAddress': ['Bang Khun Non Rd',
#          'บางกอกน้อย',
#          'กรุงเทพมหานคร 10700',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.77226574904896,
#           'lng': 100.4684410214013}],
#         'lat': 13.77226574904896,
#         'lng': 100.4684410214013,
#         'postalCode': '10700',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'สวนเฉลิมพระเกียรติ ๘๐ พรรษา พระบาทสมเด็จพระเจ้าอยู่หัว',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c16c642955976b0e31ba5f6-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d12f951735',
#          'name': 'Resort',
#          'pluralName': 'Resorts',
#          'primary': True,
#          'shortName': 'Resort'}],
#        'id': '4c16c642955976b0e31ba5f6',
#        'location': {'address': '48 Oriental Ave',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 4598,
#         'formattedAddress': ['48 Oriental Ave',
#          'พระนคร',
#          'กรุงเทพมหานคร 10500',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.7239926,
#           'lng': 100.5142411}],
#         'lat': 13.7239926,
#         'lng': 100.5142411,
#         'postalCode': '10500',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Mandarin Oriental, Bangkok',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-500532c6e4b0f0192ae31b47-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '500532c6e4b0f0192ae31b47',
#        'location': {'address': '3/2 Khao Rd',
#         'cc': 'TH',
#         'city': 'ดุสิต',
#         'country': 'ประเทศไทย',
#         'distance': 2197,
#         'formattedAddress': ['3/2 Khao Rd',
#          'ดุสิต',
#          'กรุงเทพมหานคร 10300',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.781878757576028,
#           'lng': 100.50477541525963}],
#         'lat': 13.781878757576028,
#         'lng': 100.50477541525963,
#         'postalCode': '10300',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'The Siam',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bfde0aef7c82d7fa0e98e04-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4bfde0aef7c82d7fa0e98e04',
#        'location': {'address': 'Royal Bangkok Sports Club',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'Henri Dunant Rd',
#         'distance': 4709,
#         'formattedAddress': ['Royal Bangkok Sports Club (Henri Dunant Rd)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.739676389224387,
#           'lng': 100.53609735924066}],
#         'lat': 13.739676389224387,
#         'lng': 100.53609735924066,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'RBSC Fitness Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54a15cd5498e598692a22594-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '54a15cd5498e598692a22594',
#        'location': {'address': '42 Soi Ari 5',
#         'cc': 'TH',
#         'city': 'พญาไท',
#         'country': 'ประเทศไทย',
#         'distance': 4609,
#         'formattedAddress': ['42 Soi Ari 5',
#          'พญาไท',
#          'กรุงเทพมหานคร 10400',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.779563343964318,
#           'lng': 100.538590870639}],
#         'lat': 13.779563343964318,
#         'lng': 100.538590870639,
#         'postalCode': '10400',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Hanazen (ฮานะเซน)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dfb0210d164f73de7cbbcd3-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b3c',
#          'name': 'Massage Studio',
#          'pluralName': 'Massage Studios',
#          'primary': True,
#          'shortName': 'Massage Studio'}],
#        'id': '4dfb0210d164f73de7cbbcd3',
#        'location': {'address': '2 SanamChai Rd, Pranakhon',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'Maharaj Rd, Pranakhon',
#         'distance': 1898,
#         'formattedAddress': ['2 SanamChai Rd, Pranakhon (Maharaj Rd, Pranakhon)',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.746596,
#           'lng': 100.4941}],
#         'lat': 13.746596,
#         'lng': 100.4941,
#         'neighborhood': 'Phra Borom Maha Ratchawang',
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Wat Pho Thai Traditional Medical and Massage School',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5131c9a5e4b09cc35d6934f3-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'id': '56aa371be4b08b9a8d573520',
#          'name': 'Tour Provider',
#          'pluralName': 'Tour Providers',
#          'primary': True,
#          'shortName': 'Tour Provider'}],
#        'id': '5131c9a5e4b09cc35d6934f3',
#        'location': {'address': '23 Charoen Krung Road, Soi 24',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 3903,
#         'formattedAddress': ['23 Charoen Krung Road, Soi 24',
#          'พระนคร',
#          'กรุงเทพมหานคร 10100',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.73055252984124,
#           'lng': 100.5138346153356}],
#         'lat': 13.73055252984124,
#         'lng': 100.5138346153356,
#         'postalCode': '10100',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Co van Kessel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-532c0ca5498e9f9699c35813-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'primary': True,
#          'shortName': 'Historic Site'}],
#        'id': '532c0ca5498e9f9699c35813',
#        'location': {'address': 'Wat Arun Rajwararam',
#         'cc': 'TH',
#         'city': 'บางกอกใหญ่',
#         'country': 'ประเทศไทย',
#         'distance': 2418,
#         'formattedAddress': ['Wat Arun Rajwararam',
#          'บางกอกใหญ่',
#          'กรุงเทพมหานคร 10600',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.743696,
#           'lng': 100.48893}],
#         'lat': 13.743696,
#         'lng': 100.48893,
#         'neighborhood': 'Wat Arun',
#         'postalCode': '10600',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Wat Arun Prang (พระปรางค์วัดอรุณฯ)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-592fd22df5e9d71a33527d14-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'primary': True,
#          'shortName': 'Thai'}],
#        'id': '592fd22df5e9d71a33527d14',
#        'location': {'address': '392/25-26 Maha Rat Rd',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 2242,
#         'formattedAddress': ['392/25-26 Maha Rat Rd',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.744162008588983,
#           'lng': 100.4916997083078}],
#         'lat': 13.744162008588983,
#         'lng': 100.4916997083078,
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Supanniga Eating Room x Roots Coffee (ห้องทานข้าวสุพรรณิการ์ บาย คุณยาย x รูทส์ คอฟฟี่)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bee67afd355a5933cdb0a60-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'primary': True,
#          'shortName': 'Spa'}],
#        'id': '4bee67afd355a5933cdb0a60',
#        'location': {'address': '156 Rambuttri Rd',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 376,
#         'formattedAddress': ['156 Rambuttri Rd',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.759521804989552,
#           'lng': 100.49869412600889}],
#         'lat': 13.759521804989552,
#         'lng': 100.49869412600889,
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Pai Spa (ปัยย์สปา บ้านรามบุตรี)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d7f5c0a4219a1cdedaa72d3-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'id': '56aa371be4b08b9a8d573502',
#          'name': 'Som Tum Restaurant',
#          'pluralName': 'Som Tum Restaurants',
#          'primary': True,
#          'shortName': 'Som Tum'}],
#        'id': '4d7f5c0a4219a1cdedaa72d3',
#        'location': {'address': 'Pin Ngeun Pin Tong Plaza',
#         'cc': 'TH',
#         'city': 'บางพลัด',
#         'country': 'ประเทศไทย',
#         'distance': 3024,
#         'formattedAddress': ['Pin Ngeun Pin Tong Plaza',
#          'บางพลัด',
#          'กรุงเทพมหานคร 10700',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.779375097670426,
#           'lng': 100.47746451036217}],
#         'lat': 13.779375097670426,
#         'lng': 100.47746451036217,
#         'postalCode': '10700',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Ta Bun Tum (ตะบันตำ)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b41cdfbf964a52009c925e3-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'primary': True,
#          'shortName': 'Supermarket'}],
#        'id': '4b41cdfbf964a52009c925e3',
#        'location': {'address': 'Siam Paragon',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'G Fl',
#         'distance': 4197,
#         'formattedAddress': ['Siam Paragon (G Fl)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.746354153183773,
#           'lng': 100.53455026968452}],
#         'lat': 13.746354153183773,
#         'lng': 100.53455026968452,
#         'neighborhood': 'Pathum Wan',
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Gourmet Market (กูร์เมต์ มาร์เก็ต)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51a257a5498e7f0ebdea7108-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'primary': True,
#          'shortName': 'Hostel'}],
#        'id': '51a257a5498e7f0ebdea7108',
#        'location': {'address': '55/39 Soi Kolit',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 3761,
#         'formattedAddress': ['55/39 Soi Kolit',
#          'พญาไท',
#          'กรุงเทพมหานคร 10400',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.755930720874755,
#           'lng': 100.53367786842162}],
#         'lat': 13.755930720874755,
#         'lng': 100.53367786842162,
#         'postalCode': '10400',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'In a Box Hostel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58edbb2214f8f4278e385b8f-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '58edbb2214f8f4278e385b8f',
#        'location': {'address': 'Siam Center',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': '2nd Fl',
#         'distance': 3940,
#         'formattedAddress': ['Siam Center (2nd Fl)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.746508592388071,
#           'lng': 100.53197353879868}],
#         'lat': 13.746508592388071,
#         'lng': 100.53197353879868,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Tonkatsu Wako (หมูทอด วาโก)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4baaeda4f964a520428e3ae3-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'primary': True,
#          'shortName': 'Historic Site'}],
#        'id': '4baaeda4f964a520428e3ae3',
#        'location': {'address': '315 Ratchawithi Rd',
#         'cc': 'TH',
#         'city': 'ราชเทวี',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'at Phramongkutklao Hospital',
#         'distance': 3637,
#         'formattedAddress': ['315 Ratchawithi Rd (at Phramongkutklao Hospital)',
#          'ราชเทวี',
#          'กรุงเทพมหานคร 10400',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.768418538434307,
#           'lng': 100.5327558517456}],
#         'lat': 13.768418538434307,
#         'lng': 100.5327558517456,
#         'postalCode': '10400',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Phya Thai Palace (พระราชวังพญาไท)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54a8c73f498e9be466164ab5-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'primary': True,
#          'shortName': 'Hostel'}],
#        'id': '54a8c73f498e9be466164ab5',
#        'location': {'address': '51 Soi Phahon Yothin 5',
#         'cc': 'TH',
#         'city': 'พญาไท',
#         'country': 'ประเทศไทย',
#         'distance': 4795,
#         'formattedAddress': ['51 Soi Phahon Yothin 5',
#          'พญาไท',
#          'กรุงเทพมหานคร 10400',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.776261438263981,
#           'lng': 100.54174442102409}],
#         'lat': 13.776261438263981,
#         'lng': 100.54174442102409,
#         'postalCode': '10400',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'The Yard (บ้านญาติ โฮสเทล)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c2adbf3ae6820a1e9011743-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '4c2adbf3ae6820a1e9011743',
#        'location': {'address': '1125-1127 Rama IV Rd',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'distance': 4104,
#         'formattedAddress': ['1125-1127 Rama IV Rd',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.734807,
#           'lng': 100.52434}],
#         'lat': 13.734807,
#         'lng': 100.52434,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Rod Dee Det (รสดีเด็ด)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5018bda2e4b08d7ed9d92efa-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '5018bda2e4b08d7ed9d92efa',
#        'location': {'address': 'Itsaraphap Rd.',
#         'cc': 'TH',
#         'city': 'บางกอกน้อย',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'at Nantha Uthayan Samosorn',
#         'distance': 2597,
#         'formattedAddress': ['Itsaraphap Rd. (at Nantha Uthayan Samosorn)',
#          'บางกอกน้อย',
#          'กรุงเทพมหานคร 10700',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.751463535278244,
#           'lng': 100.47860499448731}],
#         'lat': 13.751463535278244,
#         'lng': 100.47860499448731,
#         'postalCode': '10700',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Mont Nom Sod (มนต์นมสด)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c20b858d8b5b7132385dbec-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4c20b858d8b5b7132385dbec',
#        'location': {'address': '991/9 Rama I Rd',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'distance': 4161,
#         'formattedAddress': ['991/9 Rama I Rd',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.748260167423403,
#           'lng': 100.53507371971705}],
#         'lat': 13.748260167423403,
#         'lng': 100.53507371971705,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Siam Kempinski Hotel Bangkok',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c4b9a6e9c8d2d7f44e2286b-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '4c4b9a6e9c8d2d7f44e2286b',
#        'location': {'address': 'Phraeng Phuthon',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 1246,
#         'formattedAddress': ['Phraeng Phuthon',
#          'พระนคร',
#          'กรุงเทพมหานคร 10200',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.751772178605945,
#           'lng': 100.49752735845928}],
#         'lat': 13.751772178605945,
#         'lng': 100.49752735845928,
#         'postalCode': '10200',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Nattaporn Ice cream (นัฐพร ไอศครีมกะทิสดแท้)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587fdf964a52034ab22e3-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'primary': True,
#          'shortName': 'Mall'}],
#        'id': '4b0587fdf964a52034ab22e3',
#        'location': {'address': '991 Rama I Rd',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'distance': 4202,
#         'formattedAddress': ['991 Rama I Rd',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.746979229315318,
#           'lng': 100.53491234779358}],
#         'lat': 13.746979229315318,
#         'lng': 100.53491234779358,
#         'neighborhood': 'ปทุมวัน',
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Siam Paragon (สยามพารากอน)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54114fb1498e6999c97d5e1a-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'primary': True,
#          'shortName': 'Desserts'}],
#        'id': '54114fb1498e6999c97d5e1a',
#        'location': {'address': 'Siam Square One',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'crossStreet': '1st Fl.',
#         'distance': 4231,
#         'formattedAddress': ['Siam Square One (1st Fl.)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.744226759320874,
#           'lng': 100.53376708453843}],
#         'lat': 13.744226759320874,
#         'lng': 100.53376708453843,
#         'neighborhood': 'Pathum Wan',
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'After You (อาฟเตอร์ ยู)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587f8f964a5208fa922e3-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'primary': True,
#          'shortName': 'Hotel Bar'}],
#        'id': '4b0587f8f964a5208fa922e3',
#        'location': {'address': '48 Oriental Avenue',
#         'cc': 'TH',
#         'city': 'พระนคร',
#         'country': 'ประเทศไทย',
#         'distance': 4571,
#         'formattedAddress': ['48 Oriental Avenue',
#          'พระนคร',
#          'กรุงเทพมหานคร 10500',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.7241436,
#           'lng': 100.5139267}],
#         'lat': 13.7241436,
#         'lng': 100.5139267,
#         'postalCode': '10500',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'The Bamboo Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587fcf964a52002ab22e3-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'primary': True,
#          'shortName': 'Mall'}],
#        'id': '4b0587fcf964a52002ab22e3',
#        'location': {'address': '999/9 Rama I Rd',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'Ratchadamri Rd',
#         'distance': 4660,
#         'formattedAddress': ['999/9 Rama I Rd (Ratchadamri Rd)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'lat': 13.74664580692352,
#         'lng': 100.53938158613465,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'centralwOrld (เซ็นทรัลเวิลด์)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0d131ff964a520a04323e3-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'primary': True,
#          'shortName': 'Cineplex'}],
#        'id': '4b0d131ff964a520a04323e3',
#        'location': {'address': 'Siam Paragon',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': '5th-6th Fl',
#         'distance': 4270,
#         'formattedAddress': ['Siam Paragon (5th-6th Fl)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.745879026615864,
#           'lng': 100.53506244588786}],
#         'lat': 13.745879026615864,
#         'lng': 100.53506244588786,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Paragon Cineplex (พารากอน ซีนีเพล็กซ์)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d1c70a47e10a35d342eff82-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'primary': True,
#          'shortName': 'Desserts'}],
#        'id': '4d1c70a47e10a35d342eff82',
#        'location': {'address': 'Siam Paragon',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'G Fl.',
#         'distance': 4143,
#         'formattedAddress': ['Siam Paragon (G Fl.)',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.746760556467747,
#           'lng': 100.53420180451687}],
#         'lat': 13.746760556467747,
#         'lng': 100.53420180451687,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'After You (อาฟเตอร์ ยู)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c11c79ba9420f47e66e7d51-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'primary': True,
#          'shortName': 'Thai'}],
#        'id': '4c11c79ba9420f47e66e7d51',
#        'location': {'address': 'สามย่าน',
#         'cc': 'TH',
#         'city': 'ปทุมวัน',
#         'country': 'ประเทศไทย',
#         'distance': 4396,
#         'formattedAddress': ['สามย่าน',
#          'ปทุมวัน',
#          'กรุงเทพมหานคร 10330',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.734144100977481,
#           'lng': 100.52760866390587}],
#         'lat': 13.734144100977481,
#         'lng': 100.52760866390587,
#         'postalCode': '10330',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'สุกี้สามย่าน',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587f6f964a52030a922e3-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4b0587f6f964a52030a922e3',
#        'location': {'address': '333 Charoen Nakhon Rd',
#         'cc': 'TH',
#         'city': 'คลองสาน',
#         'country': 'ประเทศไทย',
#         'distance': 4600,
#         'formattedAddress': ['333 Charoen Nakhon Rd',
#          'คลองสาน',
#          'กรุงเทพมหานคร 10600',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.723022223223593,
#           'lng': 100.51121771335602}],
#         'lat': 13.723022223223593,
#         'lng': 100.51121771335602,
# ...
#          'เขตคลองเตย',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.745626,
#           'lng': 100.556366}],
#         'lat': 13.745626,
#         'lng': 100.556366,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Charcoal Tandoor Grill & Mixology',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94394468'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55191569498e18feb9544baa-88',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'primary': True,
#          'shortName': 'Mall'}],
#        'id': '55191569498e18feb9544baa',
#        'location': {'address': '693,695 Sukhumvit Rd',
#         'cc': 'TH',
#         'city': 'คลองเตย',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'btwn Soi 35 & 37',
#         'distance': 8335,
#         'formattedAddress': ['693,695 Sukhumvit Rd (btwn Soi 35 & 37)',
#          'คลองเตย',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.73137055274451,
#           'lng': 100.56958794593811}],
#         'lat': 13.73137055274451,
#         'lng': 100.56958794593811,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'EmQuartier (เอ็มควอเทียร์)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50b7701ce4b0c9f8dc6863c4-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '50b7701ce4b0c9f8dc6863c4',
#        'location': {'address': '808/13 Thararom 2',
#         'cc': 'TH',
#         'city': 'วัฒนา',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'Sukhumvit 55',
#         'distance': 9618,
#         'formattedAddress': ['808/13 Thararom 2 (Sukhumvit 55)',
#          'วัฒนา',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.73677,
#           'lng': 100.58444}],
#         'lat': 13.73677,
#         'lng': 100.58444,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': "Kenji's Lab",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54addec5498e0da4bfe14445-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_',
#           'suffix': '.png'},
#          'id': '53e510b7498ebcb1801b55d4',
#          'name': 'Night Market',
#          'pluralName': 'Night Markets',
#          'primary': True,
#          'shortName': 'Night Market'}],
#        'id': '54addec5498e0da4bfe14445',
#        'location': {'address': 'Ratchadaphisek Rd',
#         'cc': 'TH',
#         'city': 'Din Daeng',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'behind Esplanade Ratchadaphisek',
#         'distance': 7496,
#         'formattedAddress': ['Ratchadaphisek Rd (behind Esplanade Ratchadaphisek)',
#          'Din Daeng',
#          'กรุงเทพมหานคร 10400',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.766791088179174,
#           'lng': 100.56882721500156}],
#         'lat': 13.766791088179174,
#         'lng': 100.56882721500156,
#         'postalCode': '10400',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Train Night Market Ratchada (ตลาดนัดรถไฟ รัชดา)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ba1c25ff964a52033cb37e3-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'id': '4ba1c25ff964a52033cb37e3',
#        'location': {'address': '293 Ekkamai Rd',
#         'cc': 'TH',
#         'city': 'วัฒนา',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'at Soi 15',
#         'distance': 10025,
#         'formattedAddress': ['293 Ekkamai Rd (at Soi 15)',
#          'วัฒนา',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.734906083787719,
#           'lng': 100.58777773910936}],
#         'lat': 13.734906083787719,
#         'lng': 100.58777773910936,
#         'neighborhood': 'Vadhana',
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Arunwan (อรุณวรรณ)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bdb6cf363c5c9b66cf22768-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4bdb6cf363c5c9b66cf22768',
#        'location': {'address': 'Rama III Rd',
#         'cc': 'TH',
#         'city': 'บางคอแหลม',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'near Rama IX Bridge',
#         'distance': 8818,
#         'formattedAddress': ['Rama III Rd (near Rama IX Bridge)',
#          'บางคอแหลม',
#          'กรุงเทพมหานคร 10120',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.685723688067712,
#           'lng': 100.51852425355858}],
#         'lat': 13.685723688067712,
#         'lng': 100.51852425355858,
#         'postalCode': '10120',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Chaaloem Phrakiat Park (สวนสาธารณะเฉลิมพระเกียรติ 6 รอบ)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52e4d506498ea9ece63bb0eb-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '52e4d506498ea9ece63bb0eb',
#        'location': {'address': 'K-Village',
#         'cc': 'TH',
#         'city': 'คลองเตย',
#         'country': 'ประเทศไทย',
#         'crossStreet': '93, 95 Sukhumvit 26',
#         'distance': 8860,
#         'formattedAddress': ['K-Village (93, 95 Sukhumvit 26)',
#          'คลองเตย',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.721022985405543,
#           'lng': 100.56937366609165}],
#         'lat': 13.721022985405543,
#         'lng': 100.56937366609165,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'manycups',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '78850654'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b989229f964a520474735e3-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'primary': True,
#          'shortName': 'Sushi'}],
#        'id': '4b989229f964a520474735e3',
#        'location': {'address': '5 Soi Sukhumvit 31',
#         'cc': 'TH',
#         'city': 'วัฒนา',
#         'country': 'ประเทศไทย',
#         'distance': 7877,
#         'formattedAddress': ['5 Soi Sukhumvit 31',
#          'วัฒนา',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.734558407918616,
#           'lng': 100.56641749207378}],
#         'lat': 13.734558407918616,
#         'lng': 100.56641749207378,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'ISAO (อิซาโอะ)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b6173aaf964a5200c142ae3-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'primary': True,
#          'shortName': 'Spa'}],
#        'id': '4b6173aaf964a5200c142ae3',
#        'location': {'address': '64 Sukhumvit 31',
#         'cc': 'TH',
#         'city': 'วัฒนา',
#         'country': 'ประเทศไทย',
#         'distance': 7810,
#         'formattedAddress': ['64 Sukhumvit 31',
#          'วัฒนา',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.740832683338237,
#           'lng': 100.56822486330783}],
#         'lat': 13.740832683338237,
#         'lng': 100.56822486330783,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'The Oasis Spa',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e61e71752b1260c12e36559-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '4e61e71752b1260c12e36559',
#        'location': {'address': '684 Rama III Rd.',
#         'cc': 'TH',
#         'city': 'ยานนาวา',
#         'country': 'ประเทศไทย',
#         'distance': 9921,
#         'formattedAddress': ['684 Rama III Rd.',
#          'ยานนาวา',
#          'กรุงเทพมหานคร 10120',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.677992590801482,
#           'lng': 100.52788741578124}],
#         'lat': 13.677992590801482,
#         'lng': 100.52788741578124,
#         'neighborhood': 'Yan Nawa',
#         'postalCode': '10120',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'ก๋วยเตี๋ยวเนื้อตุ๋นท่าน้ำสาธุฯ',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56d5928a498ea5253b41542c-97',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10d941735',
#          'name': 'German Restaurant',
#          'pluralName': 'German Restaurants',
#          'primary': True,
#          'shortName': 'German'}],
#        'id': '56d5928a498ea5253b41542c',
#        'location': {'address': '10 Soi Yen Akat 3',
#         'cc': 'TH',
#         'city': 'ยานนาวา',
#         'country': 'ประเทศไทย',
#         'distance': 7634,
#         'formattedAddress': ['10 Soi Yen Akat 3',
#          'ยานนาวา',
#          'กรุงเทพมหานคร 10120',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.710749332945863,
#           'lng': 100.54560710752581}],
#         'lat': 13.710749332945863,
#         'lng': 100.54560710752581,
#         'postalCode': '10120',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Sühring',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bbead8d006dc9b6519efb3f-98',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '4bbead8d006dc9b6519efb3f',
#        'location': {'address': '3 Soi Sun Wichai 7',
#         'cc': 'TH',
#         'city': 'ห้วยขวาง',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'next to Bangkok Hospital',
#         'distance': 9214,
#         'formattedAddress': ['3 Soi Sun Wichai 7 (next to Bangkok Hospital)',
#          'ห้วยขวาง',
#          'กรุงเทพมหานคร 10320',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.747697289941192,
#           'lng': 100.58340351100968}],
#         'lat': 13.747697289941192,
#         'lng': 100.58340351100968,
#         'neighborhood': 'Huai Khwang',
#         'postalCode': '10320',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Lookshin Anamai (ลูกชิ้น อนามัย)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51c43ab2498e7b8d3ad9fe2c-99',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '51c43ab2498e7b8d3ad9fe2c',
#        'location': {'address': '14 Sukhumvit 61',
#         'cc': 'TH',
#         'city': 'วัฒนา',
#         'country': 'ประเทศไทย',
#         'crossStreet': 'Sukhumvit',
#         'distance': 10087,
#         'formattedAddress': ['14 Sukhumvit 61 (Sukhumvit)',
#          'วัฒนา',
#          'กรุงเทพมหานคร 10110',
#          'ประเทศไทย'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.722948072234914,
#           'lng': 100.58340138893769}],
#         'lat': 13.722948072234914,
#         'lng': 100.58340138893769,
#         'postalCode': '10110',
#         'state': 'กรุงเทพมหานคร'},
#        'name': 'Teppen (เท้ปเป้น)',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Bangkok',
#   'headerLocation': 'Bangkok',
#   'headerLocationGranularity': 'city',
#   'suggestedBounds': {'ne': {'lat': 14.662787100000902,
#     'lng': 101.42448856591272},
#    'sw': {'lat': 12.8627852999991, 'lng': 99.57473943408726}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 193}}

# %%
# Grabbing the data.
venues = results['response']['groups'][0]['items']

all_venues = json_normalize(venues)

all_venues.columns
# Out:
# Index(['reasons.count', 'reasons.items', 'referralId', 'venue.categories',
#        'venue.id', 'venue.location.address', 'venue.location.cc',
#        'venue.location.city', 'venue.location.country',
#        'venue.location.crossStreet', 'venue.location.distance',
#        'venue.location.formattedAddress', 'venue.location.labeledLatLngs',
#        'venue.location.lat', 'venue.location.lng',
#        'venue.location.neighborhood', 'venue.location.postalCode',
#        'venue.location.state', 'venue.name', 'venue.photos.count',
#        'venue.photos.groups', 'venue.venuePage.id'],
#       dtype='object')

# %%
# Lets look at the raw data.
print(all_venues.shape)
all_venues.head()
# Out:
# (100, 22)
#    reasons.count                                      reasons.items  \
# 0              0  [{'summary': 'This spot is popular', 'type': '...
# 1              0  [{'summary': 'This spot is popular', 'type': '...
# 2              0  [{'summary': 'This spot is popular', 'type': '...
# 3              0  [{'summary': 'This spot is popular', 'type': '...
# 4              0  [{'summary': 'This spot is popular', 'type': '...
#
#                        referralId  \
# 0  e-0-4dfb6e666284607895334ba5-0
# 1  e-0-4fd6b0f0e4b0a25e3aaaa1ff-1
# 2  e-0-4b0587f9f964a52001aa22e3-2
# 3  e-0-4e3105c381302aa582e214a7-3
# 4  e-0-4b492992f964a520596826e3-4
#
#                                     venue.categories  \
# 0  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# 2  [{'id': '52e81612bcbc57f1066b7a3e', 'name': 'B...
# 3  [{'id': '52e81612bcbc57f1066b7a14', 'name': 'P...
# 4  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...
#
#                    venue.id  venue.location.address venue.location.cc  \
# 0  4dfb6e666284607895334ba5              Samsen Rd.                TH
# 1  4fd6b0f0e4b0a25e3aaaa1ff                      23                TH
# 2  4b0587f9f964a52001aa22e3          Na Phra Lan Rd                TH
# 3  4e3105c381302aa582e214a7        The Grand Palace                TH
# 4  4b492992f964a520596826e3  151/1 Nakhon Chaisi Rd                TH
#
#   venue.location.city venue.location.country venue.location.crossStreet  ...  \
# 0              พระนคร              ประเทศไทย                        NaN  ...
# 1              พระนคร              ประเทศไทย                        NaN  ...
# 2              พระนคร              ประเทศไทย                Maha Rat Rd  ...
# 3              พระนคร              ประเทศไทย                        NaN  ...
# 4               ดุสิต              ประเทศไทย                        NaN  ...
#
#                        venue.location.labeledLatLngs venue.location.lat  \
# 0  [{'label': 'display', 'lat': 13.76304315030682...          13.763043
# 1  [{'label': 'display', 'lat': 13.76230825218113...          13.762308
# 2  [{'label': 'display', 'lat': 13.75173464369186...          13.751735
# 3  [{'label': 'display', 'lat': 13.750105, 'lng':...          13.750105
# 4  [{'label': 'display', 'lat': 13.78480512163128...          13.784805
#
#   venue.location.lng  venue.location.neighborhood  venue.location.postalCode  \
# 0         100.498839                          NaN                      10200
# 1         100.493020               Chana Songkram                      10200
# 2         100.492651                          NaN                      10200
# 3         100.490524   Phra Borom Maha Ratchawang                      10200
# 4         100.512836                          NaN                      10300
#
#   venue.location.state                                         venue.name  \
# 0        กรุงเทพมหานคร                          Adhere the 13th Blues Bar
# 1        กรุงเทพมหานคร                                 Riva Surya Bangkok
# 2        กรุงเทพมหานคร  Temple of the Emerald Buddha (วัดพระศรีรัตนศาส...
# 3        กรุงเทพมหานคร  Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิต...
# 4        กรุงเทพมหานคร                 Look Chin Sri Yan (ลูกชิ้นศรีย่าน)
#
#   venue.photos.count venue.photos.groups  venue.venuePage.id
# 0                  0                  []                 NaN
# 1                  0                  []                 NaN
# 2                  0                  []                 NaN
# 3                  0                  []                 NaN
# 4                  0                  []                 NaN
#
# [5 rows x 22 columns]

# %%
# Grabbing all the data we can
for offset in range(1, 20):
    LIMIT = 100
    radius = 100000
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        latitude, 
        longitude, 
        radius, 
        LIMIT,
        offset)
    all_venues = pd.concat([all_venues, json_normalize(requests.get(url).json()['response']['groups'][0]['items'])], ignore_index=True)

all_venues.shape
# Out:
# (2000, 22)

# %%
# Looking for interesting columns that we should keep.
for c in all_venues.columns:
    try:
        print(c)
        print(all_venues[c].unique())
    except:
        continue
# Out:
# reasons.count
# [0]
# reasons.items
# referralId
# ['e-0-4dfb6e666284607895334ba5-0' 'e-0-4fd6b0f0e4b0a25e3aaaa1ff-1'
#  'e-0-4b0587f9f964a52001aa22e3-2' 'e-0-4e3105c381302aa582e214a7-3'
#  'e-0-4b492992f964a520596826e3-4' 'e-0-4da03dcfa77d816ea6b81309-5'
#  'e-0-4c80b79374d7b60cabdc6fd8-6' 'e-0-55461e9b498e777ecbdb0696-7'
#  'e-0-50568fd6e4b02204c3b9dd0b-8' 'e-0-54e2cdc7498eefaf2e840b85-9'
#  'e-0-4b377134f964a520154125e3-10' 'e-0-509a31b8e4b07ae84f975465-11'
#  'e-0-4c16c642955976b0e31ba5f6-12' 'e-0-500532c6e4b0f0192ae31b47-13'
#  'e-0-4bfde0aef7c82d7fa0e98e04-14' 'e-0-54a15cd5498e598692a22594-15'
#  'e-0-4dfb0210d164f73de7cbbcd3-16' 'e-0-5131c9a5e4b09cc35d6934f3-17'
#  'e-0-532c0ca5498e9f9699c35813-18' 'e-0-592fd22df5e9d71a33527d14-19'
#  'e-0-4bee67afd355a5933cdb0a60-20' 'e-0-4d7f5c0a4219a1cdedaa72d3-21'
#  'e-0-4b41cdfbf964a52009c925e3-22' 'e-0-51a257a5498e7f0ebdea7108-23'
#  'e-0-58edbb2214f8f4278e385b8f-24' 'e-0-4baaeda4f964a520428e3ae3-25'
#  'e-0-54a8c73f498e9be466164ab5-26' 'e-0-4c2adbf3ae6820a1e9011743-27'
#  'e-0-5018bda2e4b08d7ed9d92efa-28' 'e-0-4c20b858d8b5b7132385dbec-29'
#  'e-0-4c4b9a6e9c8d2d7f44e2286b-30' 'e-0-4b0587fdf964a52034ab22e3-31'
#  'e-0-54114fb1498e6999c97d5e1a-32' 'e-0-4b0587f8f964a5208fa922e3-33'
#  'e-0-4b0587fcf964a52002ab22e3-34' 'e-0-4b0d131ff964a520a04323e3-35'
#  'e-0-4d1c70a47e10a35d342eff82-36' 'e-0-4c11c79ba9420f47e66e7d51-37'
#  'e-0-4b0587f6f964a52030a922e3-38' 'e-0-507781dce4b0602b617811a8-39'
#  'e-0-4b37733bf964a520204125e3-40' 'e-0-4cbe894d021ca1435c14560c-41'
#  'e-0-528cbe6311d2feb154412f25-42' 'e-0-4b5309e6f964a5203d8d27e3-43'
#  'e-0-4dabc90f5da3ba8a47a8f75d-44' 'e-0-4b6bafc8f964a5208c152ce3-45'
#  'e-0-4b8a56c2f964a520226932e3-46' 'e-0-4d7605f4c3efa09055fa4739-47'
#  'e-0-4cd0ee9f6200b1f76a46d728-48' 'e-0-4b8227c9f964a520efcb30e3-49'
#  'e-0-4b4db38cf964a520f8d526e3-50' 'e-0-4ccaa4e9c010f04d1427f0cc-51'
#  'e-0-5be46d95d552c7002ccbb459-52' 'e-0-4b77d40bf964a520b0ab2ee3-53'
#  'e-0-54f3fb1d498ee35c902104c5-54' 'e-0-4e03eb2162e1b12875a75ca1-55'
#  'e-0-4b51b2e1f964a520ed5227e3-56' 'e-0-5342772c498e1f39b74b9706-57'
#  'e-0-4bc82a2314d79521f29c68e9-58' 'e-0-4c49e1f1b5eec9b6dc675aa5-59'
#  'e-0-562f4971498e2a51cd30a199-60' 'e-0-4b75ed44f964a520722f2ee3-61'
#  'e-0-4c43e02c2d3ec9b6ee2f2eae-62' 'e-0-5630fcb4498e6064cbf85824-63'
#  'e-0-4c687ee32f6c0f478fe31b7e-64' 'e-0-4b0587f6f964a52012a922e3-65'
#  'e-0-4c5511faa724e21e92a170f7-66' 'e-0-54795975498e156b2245b3f0-67'
#  'e-0-4b85d922f964a520267631e3-68' 'e-0-55165a27498ec1fbae84ea08-69'
#  'e-0-4bd401e477b29c74300a9282-70' 'e-0-4bc3fc27920eb71393441e2c-71'
#  'e-0-4d71ab735838a093279cffda-72' 'e-0-4bca91e90687ef3bf06adccc-73'
#  'e-0-52660cc9498e0b4665826069-74' 'e-0-4b49a742f964a520307226e3-75'
#  'e-0-4c2cc5482219c9282a9ea648-76' 'e-0-502efd76e4b07730f44e0c5a-77'
#  'e-0-4c2deeffe307d13a2c960eda-78' 'e-0-4bbada1cb35776b06d61cb01-79'
#  'e-0-4c83477a2f1c236aeed54143-80' 'e-0-54ffb902498ec5a612995f9c-81'
#  'e-0-5673704d498e6031ee82fcde-82' 'e-0-4f4747b7e4b01d17b85e4431-83'
#  'e-0-5017c8d8e4b033fdaf9937b6-84' 'e-0-553f27c9498edf5cebea9639-85'
#  'e-0-58c68da8b21014507bba25d1-86' 'e-0-540eacbc498e9f07abf1da38-87'
#  'e-0-55191569498e18feb9544baa-88' 'e-0-50b7701ce4b0c9f8dc6863c4-89'
#  'e-0-54addec5498e0da4bfe14445-90' 'e-0-4ba1c25ff964a52033cb37e3-91'
#  'e-0-4bdb6cf363c5c9b66cf22768-92' 'e-0-52e4d506498ea9ece63bb0eb-93'
#  'e-0-4b989229f964a520474735e3-94' 'e-0-4b6173aaf964a5200c142ae3-95'
#  'e-0-4e61e71752b1260c12e36559-96' 'e-0-56d5928a498ea5253b41542c-97'
#  'e-0-4bbead8d006dc9b6519efb3f-98' 'e-0-51c43ab2498e7b8d3ad9fe2c-99'
#  'e-0-4bb49afd15809c748a831fdd-100' 'e-0-4bd4085b9854d13ae803ff4d-101'
#  'e-0-5704f18a498e43e4d12a8403-102' 'e-0-4d57a2d3afe4b60cc2274761-103'
#  'e-0-555d4d2e498e02e9b9c70f9f-104' 'e-0-4b6e754df964a5202ebe2ce3-105'
#  'e-0-5502feba498efd73ec602368-106' 'e-0-55b1ef6b498eb61d9f53e4dc-107'
#  'e-0-4c03c45af423a5932f9fd016-108' 'e-0-55b364f1498ec1a2f592c892-109'
#  'e-0-5139b2dee4b0257b5f4cbcd7-110' 'e-0-5763d7af498e662148cb7cd9-111'
#  'e-0-5626490a498e892e613f995d-112' 'e-0-4ce8104a8ef78cfa23c5979b-113'
#  'e-0-536cc82e498ecb8e8be007ed-114' 'e-0-4b547a36f964a520bcbc27e3-115'
#  'e-0-4e2d53f6fa76bbf847ec14f3-116' 'e-0-564d4887498e6e851e373a97-117'
#  'e-0-4c9fdbe4542b224bf44b01a0-118']
# venue.categories
# venue.id
# ['4dfb6e666284607895334ba5' '4fd6b0f0e4b0a25e3aaaa1ff'
#  '4b0587f9f964a52001aa22e3' '4e3105c381302aa582e214a7'
#  '4b492992f964a520596826e3' '4da03dcfa77d816ea6b81309'
#  '4c80b79374d7b60cabdc6fd8' '55461e9b498e777ecbdb0696'
#  '50568fd6e4b02204c3b9dd0b' '54e2cdc7498eefaf2e840b85'
#  '4b377134f964a520154125e3' '509a31b8e4b07ae84f975465'
#  '4c16c642955976b0e31ba5f6' '500532c6e4b0f0192ae31b47'
#  '4bfde0aef7c82d7fa0e98e04' '54a15cd5498e598692a22594'
#  '4dfb0210d164f73de7cbbcd3' '5131c9a5e4b09cc35d6934f3'
#  '532c0ca5498e9f9699c35813' '592fd22df5e9d71a33527d14'
#  '4bee67afd355a5933cdb0a60' '4d7f5c0a4219a1cdedaa72d3'
#  '4b41cdfbf964a52009c925e3' '51a257a5498e7f0ebdea7108'
#  '58edbb2214f8f4278e385b8f' '4baaeda4f964a520428e3ae3'
#  '54a8c73f498e9be466164ab5' '4c2adbf3ae6820a1e9011743'
#  '5018bda2e4b08d7ed9d92efa' '4c20b858d8b5b7132385dbec'
#  '4c4b9a6e9c8d2d7f44e2286b' '4b0587fdf964a52034ab22e3'
#  '54114fb1498e6999c97d5e1a' '4b0587f8f964a5208fa922e3'
#  '4b0587fcf964a52002ab22e3' '4b0d131ff964a520a04323e3'
#  '4d1c70a47e10a35d342eff82' '4c11c79ba9420f47e66e7d51'
#  '4b0587f6f964a52030a922e3' '507781dce4b0602b617811a8'
#  '4b37733bf964a520204125e3' '4cbe894d021ca1435c14560c'
#  '528cbe6311d2feb154412f25' '4b5309e6f964a5203d8d27e3'
#  '4dabc90f5da3ba8a47a8f75d' '4b6bafc8f964a5208c152ce3'
#  '4b8a56c2f964a520226932e3' '4d7605f4c3efa09055fa4739'
#  '4cd0ee9f6200b1f76a46d728' '4b8227c9f964a520efcb30e3'
#  '4b4db38cf964a520f8d526e3' '4ccaa4e9c010f04d1427f0cc'
#  '5be46d95d552c7002ccbb459' '4b77d40bf964a520b0ab2ee3'
#  '54f3fb1d498ee35c902104c5' '4e03eb2162e1b12875a75ca1'
#  '4b51b2e1f964a520ed5227e3' '5342772c498e1f39b74b9706'
#  '4bc82a2314d79521f29c68e9' '4c49e1f1b5eec9b6dc675aa5'
#  '562f4971498e2a51cd30a199' '4b75ed44f964a520722f2ee3'
#  '4c43e02c2d3ec9b6ee2f2eae' '5630fcb4498e6064cbf85824'
#  '4c687ee32f6c0f478fe31b7e' '4b0587f6f964a52012a922e3'
#  '4c5511faa724e21e92a170f7' '54795975498e156b2245b3f0'
#  '4b85d922f964a520267631e3' '55165a27498ec1fbae84ea08'
#  '4bd401e477b29c74300a9282' '4bc3fc27920eb71393441e2c'
#  '4d71ab735838a093279cffda' '4bca91e90687ef3bf06adccc'
#  '52660cc9498e0b4665826069' '4b49a742f964a520307226e3'
#  '4c2cc5482219c9282a9ea648' '502efd76e4b07730f44e0c5a'
#  '4c2deeffe307d13a2c960eda' '4bbada1cb35776b06d61cb01'
#  '4c83477a2f1c236aeed54143' '54ffb902498ec5a612995f9c'
#  '5673704d498e6031ee82fcde' '4f4747b7e4b01d17b85e4431'
#  '5017c8d8e4b033fdaf9937b6' '553f27c9498edf5cebea9639'
#  '58c68da8b21014507bba25d1' '540eacbc498e9f07abf1da38'
#  '55191569498e18feb9544baa' '50b7701ce4b0c9f8dc6863c4'
#  '54addec5498e0da4bfe14445' '4ba1c25ff964a52033cb37e3'
#  '4bdb6cf363c5c9b66cf22768' '52e4d506498ea9ece63bb0eb'
#  '4b989229f964a520474735e3' '4b6173aaf964a5200c142ae3'
#  '4e61e71752b1260c12e36559' '56d5928a498ea5253b41542c'
#  '4bbead8d006dc9b6519efb3f' '51c43ab2498e7b8d3ad9fe2c'
#  '4bb49afd15809c748a831fdd' '4bd4085b9854d13ae803ff4d'
#  '5704f18a498e43e4d12a8403' '4d57a2d3afe4b60cc2274761'
#  '555d4d2e498e02e9b9c70f9f' '4b6e754df964a5202ebe2ce3'
#  '5502feba498efd73ec602368' '55b1ef6b498eb61d9f53e4dc'
#  '4c03c45af423a5932f9fd016' '55b364f1498ec1a2f592c892'
#  '5139b2dee4b0257b5f4cbcd7' '5763d7af498e662148cb7cd9'
#  '5626490a498e892e613f995d' '4ce8104a8ef78cfa23c5979b'
#  '536cc82e498ecb8e8be007ed' '4b547a36f964a520bcbc27e3'
#  '4e2d53f6fa76bbf847ec14f3' '564d4887498e6e851e373a97'
#  '4c9fdbe4542b224bf44b01a0']
# venue.location.address
# ['Samsen Rd.' '23' 'Na Phra Lan Rd' 'The Grand Palace'
#  '151/1 Nakhon Chaisi Rd' '1/1 Soi Rambuttri' '326 Chao Khamrop Rd'
#  'Yodpiman Riverwalk' 'Siriraj Piyamaharajkarun Hospital'
#  '92/1 Krung Thonburi Road' 'Siam Paragon' 'Bang Khun Non Rd'
#  '48 Oriental Ave' '3/2 Khao Rd' 'Royal Bangkok Sports Club'
#  '42 Soi Ari 5' '2 SanamChai Rd, Pranakhon'
#  '23 Charoen Krung Road, Soi 24' 'Wat Arun Rajwararam'
#  '392/25-26 Maha Rat Rd' '156 Rambuttri Rd' 'Pin Ngeun Pin Tong Plaza'
#  '55/39 Soi Kolit' 'Siam Center' '315 Ratchawithi Rd'
#  '51 Soi Phahon Yothin 5' '1125-1127 Rama IV Rd' 'Itsaraphap Rd.'
#  '991/9 Rama I Rd' 'Phraeng Phuthon' '991 Rama I Rd' 'Siam Square One'
#  '48 Oriental Avenue' '999/9 Rama I Rd' 'สามย่าน' '333 Charoen Nakhon Rd'
#  '106 Sathon Nuea Rd' 'Isetan' 'Charansanitwong 75 Soi 4'
#  'Charoen Nakhon Rd' 'Rama IV Rd' '2 Sathon Nuea Rd.' '313/7 Chan Rd'
#  '430 Rama I Rd' 'Soi Charoen Krung 42/1' '3 Soi Mahadlek Luang 2'
#  'Soi Than Tawan' 'Soi Ratchawithi 3' '159 Ratchadamri Rd'
#  '299 Soi Charoen Nakhon 5' '40/5 Surawong Road, Bangrak, Bang Rak'
#  'Sindhorn Tower' '33/1 Sathon Tai Rd' '494 Ratchadamri Rd'
#  '403-403/1, 407-407/1 Sukhumvit Rd.' '65 Sukhumvit 1'
#  '864 Somdet Phra Chao Tak Sin Rd' '64/3 Pan Rd' 'Kamphaeng Phet 3 Rd'
#  '13/3 Sathon Tai Rd.' 'Sukumvit 11' 'ถ. ไตรมิตร'
#  '257/1-3 Charoen Nakhon Rd' 'Nikhom Rotfai Sai 2 Rd'
#  'King Chulalongkorn Memorial Hospital' '250 Sukhumvit Rd' 'EmQuartier'
#  'Kamphaeng Phet 2 Rd' '9/1 Si Wiang Rd' 'Chatuchak Weekend Market'
#  'Kamphaeng Phet 2' 'Soi Pridi' '595/12 Sukhumvit 33/1'
#  '123 Sathon Tai Rd.' 'A Square' 'Panjit Tower' 'Sunthon Kosa Rd'
#  '168 Moo 5 Phet Kasem Rd.' 'The Walk' 'Sukhumvit 33'
#  '38/8 Sukhumvit Soi 11' '693,695 Sukhumvit Rd' '808/13 Thararom 2'
#  'Ratchadaphisek Rd' '293 Ekkamai Rd' 'Rama III Rd' 'K-Village'
#  '5 Soi Sukhumvit 31' '64 Sukhumvit 31' '684 Rama III Rd.'
#  '10 Soi Yen Akat 3' '3 Soi Sun Wichai 7' '14 Sukhumvit 61'
#  '395 Soi Naradhiwat Rajanagarindra 24' 'ใกล้สะพานมหาเจษฎาบดินทร์'
#  'Phutthamonthon Sai 2 Rd' '48/6 Moo 5' 'TheRestArea' '9/3 Sukhumvit 49/4'
#  '888/6-7 26-28 Ekkamai Rd' '335/1 Soi Sukhumvit 55' 'Sukhumvit 63'
#  'Faculty of Business Administration' 'Bangkok Marriott Hotel Sukhumvit'
#  'CentralFestival Eastville' 'The Mall Bangkhae' '1/58 Sena Nikhom 1'
#  'Lat Phrao-Wang Hin Rd' 'Si Wara Rd' 'Chok Chai 4 Soi 54' 'The Bright'
#  '31/1 Moo 4']
# venue.location.cc
# ['TH']
# venue.location.city
# ['พระนคร' 'ดุสิต' 'Chana Songkhram' 'ป้อมปราบศัตรูพ่าย' 'บางกอกน้อย'
#  'ปทุมวัน' 'พญาไท' 'บางกอกใหญ่' 'บางพลัด' 'ราชเทวี' 'คลองสาน' 'บางรัก'
#  'บางคอแหลม' 'วัฒนา' 'ธนบุรี' 'จตุจักร' 'สาทร' 'สัมพันธวงศ์' 'คลองเตย'
#  'ภาษีเจริญ' 'บางใหญ่' 'เขตคลองเตย' 'Din Daeng' 'ยานนาวา' 'ห้วยขวาง'
#  'Yannawa' 'เมืองนนทบุรี' 'ทวีวัฒนา' 'บางซื่อ' 'ลาดพร้าว' 'บางแค'
#  'วังทองหลาง' 'บางขุนเทียน']
# venue.location.country
# ['ประเทศไทย']
# venue.location.crossStreet
# [nan 'Maha Rat Rd' 'at Pohtecktung Foundation'
#  '1st-2nd Fl, #D7-101, #D7-201' '2nd Fl' '3rd Fl, #309-314'
#  'Henri Dunant Rd' 'Maharaj Rd, Pranakhon' 'G Fl'
#  'at Phramongkutklao Hospital' 'at Nantha Uthayan Samosorn' '1st Fl.'
#  'Ratchadamri Rd' '5th-6th Fl' 'G Fl.' 'CentralWorld, 6th Fl'
#  'btwn Soi 17 & 19' 'Witthayu Rd, Ratchadamri Rd, Sarasin Rd'
#  'btwn Soi 42 & 44' 'Ratchadamri Rd.'
#  'btwn Surawong Rd. & Narathiwas Rajanagarindra 1'
#  'Soi Ratchawithi 1 & Rang Nam Rd' 'Wireless Rd' 'btwn Soi 21-23'
#  'Ariyasom Villa Hotel' 'Nikhom Rotfai Sai 1 Rd' 'Sukorn II'
#  'at Rot Fai Park' '3rd Fl, #3B-1' 'Phahon Yothin Rd' 'Section7'
#  'Sathorn, Soi 1' 'Sukhumvit 26' 'btwn Thong Lo 5-7' 'opp PAT Stadium'
#  'near Soi 46/2' 'at Suanplern Market' '4th Fl, #4A-1' 'btwn Soi 35 & 37'
#  'Sukhumvit 55' 'behind Esplanade Ratchadaphisek' 'at Soi 15'
#  'near Rama IX Bridge' '93, 95 Sukhumvit 26' 'next to Bangkok Hospital'
#  'Sukhumvit' 'ติดกับวัดเฉลิมพระเกียรติวรวิหาร' 'Sukhaphiban 1 Rd.'
#  'Si Rat Expy, northbound' 'Thong Lo 13' 'at C Ekkamai'
#  'at Soi Thong Lo 17' 'btw Ekamai 17 & 19' 'Kasetsart University'
#  'Sukhumvit 57 Road' 'at Foodville Zone' 'Lat Phrao Wanghin Rd.'
#  'opp Town In Town Hotel' 'G & 1st Fl' 'Ratchaphruek Rd']
# venue.location.distance
# [   88   714  1442  1720  2837   487  2357  2474  1499  4702  4261  3531
#   4598  2197  4709  4609  1898  3903  2418  2242   376  3024  4197  3761
#   3940  3637  4795  4104  2597  4161  1246  4202  4231  4571  4660  4270
#   4143  4396  4600  5533  4666  3272  5089  5754  6226  6175  4058  4746
#   5165  4992  4462  5071  4179  4947  5859  5423  4883  7336  5869  6783
#   5276  8305  6233  6382  3247  6559  8590  5186  7011  8358  6902  5221
#   7143  7462  7054  8161  5802  8710  9543  8397  7730  8261  9258  8700
#   8299  8020  6426  8335  9618  7496 10025  8818  8860  7877  7810  9921
#   7634  9214 10087  7941  9892 11274  7796  9467  8989 10070  9451 11740
#   9778 13268 11312 12555 11941 11856 11993 11619 12714]
# venue.location.formattedAddress
# venue.location.labeledLatLngs
# venue.location.lat
# [13.76304315 13.76230825 13.75173464 13.750105   13.78480512 13.76236268
#  13.74457758 13.74093665 13.75978852 13.72054164 13.7458388  13.77226575
#  13.7239926  13.78187876 13.73967639 13.77956334 13.746596   13.73055253
#  13.743696   13.74416201 13.7595218  13.7793751  13.74635415 13.75593072
#  13.74650859 13.76841854 13.77626144 13.734807   13.75146354 13.74826017
#  13.75177218 13.74697923 13.74422676 13.7241436  13.74664581 13.74587903
#  13.74676056 13.7341441  13.72302222 13.72202903 13.74715965 13.79066562
#  13.71774137 13.73098493 13.72625294 13.70914072 13.7461434  13.72237673
#  13.74055959 13.72898025 13.76261261 13.739923   13.72675347 13.7299733
#  13.73551588 13.71906206 13.74358499 13.73607297 13.74786768 13.703524
#  13.72166075 13.81586592 13.72348484 13.74561998 13.737322   13.70434034
#  13.81691145 13.732901   13.73755952 13.73090776 13.7999779  13.720631
#  13.80220177 13.8067005  13.71815764 13.73234652 13.72281182 13.71981499
#  13.72922102 13.716585   13.71707694 13.73234573 13.71710296 13.82051543
#  13.72049632 13.73123169 13.73248795 13.745626   13.73137055 13.73677
#  13.76679109 13.73490608 13.68572369 13.72102299 13.73455841 13.74083268
#  13.67799259 13.71074933 13.74769729 13.72294807 13.701563   13.84982009
#  13.76775564 13.83026594 13.8410615  13.73466191 13.7400104  13.73505581
#  13.73443125 13.84413272 13.72354925 13.80455465 13.7135278  13.8305904
#  13.82201871 13.77179578 13.8155205  13.66937948 13.86700673]
# venue.location.lng
# [100.49883861 100.49302011 100.49265146 100.490524   100.51283557
#  100.4951261  100.51075528 100.49539382 100.48609743 100.49950719
#  100.53495066 100.46844102 100.5142411  100.50477542 100.53609736
#  100.53859087 100.4941     100.51383462 100.48893    100.49169971
#  100.49869413 100.47746451 100.53455027 100.53367787 100.53197354
#  100.53275585 100.54174442 100.52434    100.47860499 100.53507372
#  100.49752736 100.53491235 100.53376708 100.5139267  100.53938159
#  100.53506245 100.5342018  100.52760866 100.51121771 100.52890687
#  100.53966522 100.49000636 100.50769414 100.54157495 100.54322246
#  100.51417039 100.53301457 100.51361062 100.54155128 100.52995099
#  100.54088688 100.540184   100.51048279 100.5304756  100.54596911
#  100.5217484  100.54022379 100.56164162 100.55168154 100.485
#  100.52387807 100.55360596 100.54067294 100.55593186 100.514274
#  100.49188409 100.55625439 100.536407   100.55903449 100.56960114
#  100.55070487 100.520797   100.55175747 100.55176735 100.54593593
#  100.56828024 100.53404733 100.56693699 100.58082679 100.561
#  100.4457919  100.5692951  100.57116747 100.44960633 100.5672838
#  100.56915796 100.56690924 100.556366   100.56958795 100.58444
#  100.56882722 100.58777774 100.51852425 100.56937367 100.56641749
#  100.56822486 100.52788742 100.54560711 100.58340351 100.58340139
#  100.537315   100.48113406 100.39546516 100.48029221 100.5338525
#  100.57754468 100.58974743 100.58222917 100.5876208  100.56873561
#  100.58051915 100.61455919 100.40810594 100.59242882 100.591708
#  100.60887826 100.59635135 100.45166304 100.45148319]
# venue.location.neighborhood
# [nan 'Chana Songkram' 'Phra Borom Maha Ratchawang' 'Wat Arun' 'Pathum Wan'
#  'ปทุมวัน' 'Lumphini' 'Watthana' 'Thonburi' 'Khlong Toei' 'Vadhana'
#  'Yan Nawa' 'Huai Khwang' 'Thawi Watthana' 'Lat Phrao' 'Bang Khun Thian']
# venue.location.postalCode
# ['10200' '10300' nan '10100' '10700' '10600' '10330' '10500' '10400'
#  '10120' '10110' '10900' 'Bangkok' '10160' '11130' '10320' '11000' '10170'
#  '10800' '10230' '10310' '10150']
# venue.location.state
# ['กรุงเทพมหานคร' 'นนทบุรี']
# venue.name
# ['Adhere the 13th Blues Bar' 'Riva Surya Bangkok'
#  'Temple of the Emerald Buddha (วัดพระศรีรัตนศาสดาราม (วัดพระแก้ว))'
#  'Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตมหาปราสาท)'
#  'Look Chin Sri Yan (ลูกชิ้นศรีย่าน)' 'Massage In Garden'
#  'Tai Hong Kong Shrine (ศาลเจ้าไต้ฮงกง)' 'Starbucks (สตาร์บัคส์)' 'ELF925'
#  'Books Kinokuniya (คิโนะคูนิยะ)'
#  'สวนเฉลิมพระเกียรติ ๘๐ พรรษา พระบาทสมเด็จพระเจ้าอยู่หัว'
#  'Mandarin Oriental, Bangkok' 'The Siam' 'RBSC Fitness Club'
#  'Hanazen (ฮานะเซน)' 'Wat Pho Thai Traditional Medical and Massage School'
#  'Co van Kessel' 'Wat Arun Prang (พระปรางค์วัดอรุณฯ)'
#  'Supanniga Eating Room x Roots Coffee (ห้องทานข้าวสุพรรณิการ์ บาย คุณยาย x รูทส์ คอฟฟี่)'
#  'Pai Spa (ปัยย์สปา บ้านรามบุตรี)' 'Ta Bun Tum (ตะบันตำ)'
#  'Gourmet Market (กูร์เมต์ มาร์เก็ต)' 'In a Box Hostel'
#  'Tonkatsu Wako (หมูทอด วาโก)' 'Phya Thai Palace (พระราชวังพญาไท)'
#  'The Yard (บ้านญาติ โฮสเทล)' 'Rod Dee Det (รสดีเด็ด)'
#  'Mont Nom Sod (มนต์นมสด)' 'Siam Kempinski Hotel Bangkok'
#  'Nattaporn Ice cream (นัฐพร ไอศครีมกะทิสดแท้)'
#  'Siam Paragon (สยามพารากอน)' 'After You (อาฟเตอร์ ยู)' 'The Bamboo Bar'
#  'centralwOrld (เซ็นทรัลเวิลด์)' 'Paragon Cineplex (พารากอน ซีนีเพล็กซ์)'
#  'สุกี้สามย่าน' 'The Peninsula Bangkok' 'W Bangkok' 'ครัวในซอย'
#  'Indian Food' 'Lumphini Park (สวนลุมพินี)' 'SO Sofitel Bangkok'
#  'Kuayjup Mr. Jo (ก๋วยจั๊บมิสเตอร์โจ)' 'Siam Center (สยามเซ็นเตอร์)'
#  "Jack's Bar" 'Hansar Bangkok' 'Katsu-Shin (คัสซึชิน)'
#  'Suan Santi Phap (สวนสันติภาพ)'
#  'The St. Regis Bangkok (โรงแรมเซนต์รีจิสต์)' 'ICONSIAM (ไอคอนสยาม)'
#  'Le Méridien Bangkok' 'Eastin Grand Hotel Sathorn'
#  'Grand Hyatt Erawan Bangkok' 'indulge' 'Na Aroon'
#  'Koa Chun Huad (กอชุนฮวด)' 'Luka (ลูก้า)'
#  'Vachirabenjatas Park (Rot Fai Park) (สวนวชิรเบญจทัศ (สวนรถไฟ))'
#  'The Sukhothai Bangkok' 'Havana Social' 'โจ๊กตลาดน้อย (เจ๊หมวยเกี้ย)'
#  'Anantara Bangkok Riverside Spa & Resort (โรงแรมอนันตรา กรุงเทพฯ ริเวอร์ไซด์ รีสอร์ท แอนด์ สปา)'
#  'หอจดหมายเหตุพุทธทาส อินทปัญโญ (BIA) Buddhadasa Indapanno Archives'
#  'Pacamara Boutique Coffee Roasters' 'Sheraton Grande Sukhumvit Bangkok'
#  'Chatuchak Weekend Market (ตลาดนัดจตุจักร)' 'Baan Somtum (บ้านส้มตำ)'
#  'Chatuchak Market Section7 Art Zone'
#  'Queen Sirikit Park (สวนสมเด็จพระนางเจ้าสิริกิติ์ฯ)' 'U Sathorn Bangkok'
#  'Custard Nakamura (คัสตาร์ดนากามุระ)' 'The Met (เดอะ เม็ท)'
#  'Yunomori (ยูโนะโมริ)' 'Ginzado (Ginzado (銀座堂))'
#  'Heng Chun Seng (เฮ้งชุนเส็ง)' 'Kha Moo Bang Wa (ขาหมูบางหว้า)'
#  'Flow House (โฟลว์ เฮาส์)' 'Another Story'
#  'Kenshin Izakaya (เคนชิน อิซากายะ)' 'Charcoal Tandoor Grill & Mixology'
#  'EmQuartier (เอ็มควอเทียร์)' "Kenji's Lab"
#  'Train Night Market Ratchada (ตลาดนัดรถไฟ รัชดา)' 'Arunwan (อรุณวรรณ)'
#  'Chaaloem Phrakiat Park (สวนสาธารณะเฉลิมพระเกียรติ 6 รอบ)' 'manycups'
#  'ISAO (อิซาโอะ)' 'The Oasis Spa' 'ก๋วยเตี๋ยวเนื้อตุ๋นท่าน้ำสาธุฯ'
#  'Sühring' 'Lookshin Anamai (ลูกชิ้น อนามัย)' 'Teppen (เท้ปเป้น)'
#  'The Oyster Bar' 'อุทยานเฉลิมกาญจนาภิเษก' 'OK Shabu Shabu'
#  'Kaizen Coffee Newold' 'The Commons (เดอะคอมม่อนส์)' 'ก๋วยเตี๋ยวนายแว่น'
#  'Octave Rooftop Lounge & Bar' 'Think Space B2S (ธิงค์สเปซ บีทูเอส)'
#  'Zong Ped Palow (ซ้งเป็ดพะโล้)' "Pho' 54 (เฝอ 54)" 'Ob Aroi (อบอร่อย)'
#  "PHO'54 (เฝอ'54)" 'Maria (มาเรีย)']
# venue.photos.count
# [0]
# venue.photos.groups
# venue.venuePage.id
# [nan '77326243' '94394468' '78850654' '544056059' '52342683']

# %%
# Grabbing interesting columns
filtered_columns = ['venue.categories', 'venue.location.city', 'venue.location.lat', 'venue.location.lng', 'venue.name']
df = all_venues.loc[:, filtered_columns]
df.head()
# Out:
#                                     venue.categories venue.location.city  \
# 0  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...              พระนคร
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...              พระนคร
# 2  [{'id': '52e81612bcbc57f1066b7a3e', 'name': 'B...              พระนคร
# 3  [{'id': '52e81612bcbc57f1066b7a14', 'name': 'P...              พระนคร
# 4  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...               ดุสิต
#
#    venue.location.lat  venue.location.lng  \
# 0           13.763043          100.498839
# 1           13.762308          100.493020
# 2           13.751735          100.492651
# 3           13.750105          100.490524
# 4           13.784805          100.512836
#
#                                           venue.name
# 0                          Adhere the 13th Blues Bar
# 1                                 Riva Surya Bangkok
# 2  Temple of the Emerald Buddha (วัดพระศรีรัตนศาส...
# 3  Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิต...
# 4                 Look Chin Sri Yan (ลูกชิ้นศรีย่าน)

# %%
# Lets look at the amount of missing data in each column.
print(df.shape)
df.isna().sum()
# Out:
# (2000, 5)
# venue.categories       0
# venue.location.city    0
# venue.location.lat     0
# venue.location.lng     0
# venue.name             0
# dtype: int64

# %%
# Looking at uniqueness of each column.
for i in df.columns:
    try:
        print(i)
        print(df[i].unique())
    except:
        continue
# Out:
# venue.categories
# venue.location.city
# ['พระนคร' 'ดุสิต' 'Chana Songkhram' 'ป้อมปราบศัตรูพ่าย' 'บางกอกน้อย'
#  'ปทุมวัน' 'พญาไท' 'บางกอกใหญ่' 'บางพลัด' 'ราชเทวี' 'คลองสาน' 'บางรัก'
#  'บางคอแหลม' 'วัฒนา' 'ธนบุรี' 'จตุจักร' 'สาทร' 'สัมพันธวงศ์' 'คลองเตย'
#  'ภาษีเจริญ' 'บางใหญ่' 'เขตคลองเตย' 'Din Daeng' 'ยานนาวา' 'ห้วยขวาง'
#  'Yannawa' 'เมืองนนทบุรี' 'ทวีวัฒนา' 'บางซื่อ' 'ลาดพร้าว' 'บางแค'
#  'วังทองหลาง' 'บางขุนเทียน']
# venue.location.lat
# [13.76304315 13.76230825 13.75173464 13.750105   13.78480512 13.76236268
#  13.74457758 13.74093665 13.75978852 13.72054164 13.7458388  13.77226575
#  13.7239926  13.78187876 13.73967639 13.77956334 13.746596   13.73055253
#  13.743696   13.74416201 13.7595218  13.7793751  13.74635415 13.75593072
#  13.74650859 13.76841854 13.77626144 13.734807   13.75146354 13.74826017
#  13.75177218 13.74697923 13.74422676 13.7241436  13.74664581 13.74587903
#  13.74676056 13.7341441  13.72302222 13.72202903 13.74715965 13.79066562
#  13.71774137 13.73098493 13.72625294 13.70914072 13.7461434  13.72237673
#  13.74055959 13.72898025 13.76261261 13.739923   13.72675347 13.7299733
#  13.73551588 13.71906206 13.74358499 13.73607297 13.74786768 13.703524
#  13.72166075 13.81586592 13.72348484 13.74561998 13.737322   13.70434034
#  13.81691145 13.732901   13.73755952 13.73090776 13.7999779  13.720631
#  13.80220177 13.8067005  13.71815764 13.73234652 13.72281182 13.71981499
#  13.72922102 13.716585   13.71707694 13.73234573 13.71710296 13.82051543
#  13.72049632 13.73123169 13.73248795 13.745626   13.73137055 13.73677
#  13.76679109 13.73490608 13.68572369 13.72102299 13.73455841 13.74083268
#  13.67799259 13.71074933 13.74769729 13.72294807 13.701563   13.84982009
#  13.76775564 13.83026594 13.8410615  13.73466191 13.7400104  13.73505581
#  13.73443125 13.84413272 13.72354925 13.80455465 13.7135278  13.8305904
#  13.82201871 13.77179578 13.8155205  13.66937948 13.86700673]
# venue.location.lng
# [100.49883861 100.49302011 100.49265146 100.490524   100.51283557
#  100.4951261  100.51075528 100.49539382 100.48609743 100.49950719
#  100.53495066 100.46844102 100.5142411  100.50477542 100.53609736
#  100.53859087 100.4941     100.51383462 100.48893    100.49169971
#  100.49869413 100.47746451 100.53455027 100.53367787 100.53197354
#  100.53275585 100.54174442 100.52434    100.47860499 100.53507372
#  100.49752736 100.53491235 100.53376708 100.5139267  100.53938159
#  100.53506245 100.5342018  100.52760866 100.51121771 100.52890687
#  100.53966522 100.49000636 100.50769414 100.54157495 100.54322246
#  100.51417039 100.53301457 100.51361062 100.54155128 100.52995099
#  100.54088688 100.540184   100.51048279 100.5304756  100.54596911
#  100.5217484  100.54022379 100.56164162 100.55168154 100.485
#  100.52387807 100.55360596 100.54067294 100.55593186 100.514274
#  100.49188409 100.55625439 100.536407   100.55903449 100.56960114
#  100.55070487 100.520797   100.55175747 100.55176735 100.54593593
#  100.56828024 100.53404733 100.56693699 100.58082679 100.561
#  100.4457919  100.5692951  100.57116747 100.44960633 100.5672838
#  100.56915796 100.56690924 100.556366   100.56958795 100.58444
#  100.56882722 100.58777774 100.51852425 100.56937367 100.56641749
#  100.56822486 100.52788742 100.54560711 100.58340351 100.58340139
#  100.537315   100.48113406 100.39546516 100.48029221 100.5338525
#  100.57754468 100.58974743 100.58222917 100.5876208  100.56873561
#  100.58051915 100.61455919 100.40810594 100.59242882 100.591708
#  100.60887826 100.59635135 100.45166304 100.45148319]
# venue.name
# ['Adhere the 13th Blues Bar' 'Riva Surya Bangkok'
#  'Temple of the Emerald Buddha (วัดพระศรีรัตนศาสดาราม (วัดพระแก้ว))'
#  'Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตมหาปราสาท)'
#  'Look Chin Sri Yan (ลูกชิ้นศรีย่าน)' 'Massage In Garden'
#  'Tai Hong Kong Shrine (ศาลเจ้าไต้ฮงกง)' 'Starbucks (สตาร์บัคส์)' 'ELF925'
#  'Books Kinokuniya (คิโนะคูนิยะ)'
#  'สวนเฉลิมพระเกียรติ ๘๐ พรรษา พระบาทสมเด็จพระเจ้าอยู่หัว'
#  'Mandarin Oriental, Bangkok' 'The Siam' 'RBSC Fitness Club'
#  'Hanazen (ฮานะเซน)' 'Wat Pho Thai Traditional Medical and Massage School'
#  'Co van Kessel' 'Wat Arun Prang (พระปรางค์วัดอรุณฯ)'
#  'Supanniga Eating Room x Roots Coffee (ห้องทานข้าวสุพรรณิการ์ บาย คุณยาย x รูทส์ คอฟฟี่)'
#  'Pai Spa (ปัยย์สปา บ้านรามบุตรี)' 'Ta Bun Tum (ตะบันตำ)'
#  'Gourmet Market (กูร์เมต์ มาร์เก็ต)' 'In a Box Hostel'
#  'Tonkatsu Wako (หมูทอด วาโก)' 'Phya Thai Palace (พระราชวังพญาไท)'
#  'The Yard (บ้านญาติ โฮสเทล)' 'Rod Dee Det (รสดีเด็ด)'
#  'Mont Nom Sod (มนต์นมสด)' 'Siam Kempinski Hotel Bangkok'
#  'Nattaporn Ice cream (นัฐพร ไอศครีมกะทิสดแท้)'
#  'Siam Paragon (สยามพารากอน)' 'After You (อาฟเตอร์ ยู)' 'The Bamboo Bar'
#  'centralwOrld (เซ็นทรัลเวิลด์)' 'Paragon Cineplex (พารากอน ซีนีเพล็กซ์)'
#  'สุกี้สามย่าน' 'The Peninsula Bangkok' 'W Bangkok' 'ครัวในซอย'
#  'Indian Food' 'Lumphini Park (สวนลุมพินี)' 'SO Sofitel Bangkok'
#  'Kuayjup Mr. Jo (ก๋วยจั๊บมิสเตอร์โจ)' 'Siam Center (สยามเซ็นเตอร์)'
#  "Jack's Bar" 'Hansar Bangkok' 'Katsu-Shin (คัสซึชิน)'
#  'Suan Santi Phap (สวนสันติภาพ)'
#  'The St. Regis Bangkok (โรงแรมเซนต์รีจิสต์)' 'ICONSIAM (ไอคอนสยาม)'
#  'Le Méridien Bangkok' 'Eastin Grand Hotel Sathorn'
#  'Grand Hyatt Erawan Bangkok' 'indulge' 'Na Aroon'
#  'Koa Chun Huad (กอชุนฮวด)' 'Luka (ลูก้า)'
#  'Vachirabenjatas Park (Rot Fai Park) (สวนวชิรเบญจทัศ (สวนรถไฟ))'
#  'The Sukhothai Bangkok' 'Havana Social' 'โจ๊กตลาดน้อย (เจ๊หมวยเกี้ย)'
#  'Anantara Bangkok Riverside Spa & Resort (โรงแรมอนันตรา กรุงเทพฯ ริเวอร์ไซด์ รีสอร์ท แอนด์ สปา)'
#  'หอจดหมายเหตุพุทธทาส อินทปัญโญ (BIA) Buddhadasa Indapanno Archives'
#  'Pacamara Boutique Coffee Roasters' 'Sheraton Grande Sukhumvit Bangkok'
#  'Chatuchak Weekend Market (ตลาดนัดจตุจักร)' 'Baan Somtum (บ้านส้มตำ)'
#  'Chatuchak Market Section7 Art Zone'
#  'Queen Sirikit Park (สวนสมเด็จพระนางเจ้าสิริกิติ์ฯ)' 'U Sathorn Bangkok'
#  'Custard Nakamura (คัสตาร์ดนากามุระ)' 'The Met (เดอะ เม็ท)'
#  'Yunomori (ยูโนะโมริ)' 'Ginzado (Ginzado (銀座堂))'
#  'Heng Chun Seng (เฮ้งชุนเส็ง)' 'Kha Moo Bang Wa (ขาหมูบางหว้า)'
#  'Flow House (โฟลว์ เฮาส์)' 'Another Story'
#  'Kenshin Izakaya (เคนชิน อิซากายะ)' 'Charcoal Tandoor Grill & Mixology'
#  'EmQuartier (เอ็มควอเทียร์)' "Kenji's Lab"
#  'Train Night Market Ratchada (ตลาดนัดรถไฟ รัชดา)' 'Arunwan (อรุณวรรณ)'
#  'Chaaloem Phrakiat Park (สวนสาธารณะเฉลิมพระเกียรติ 6 รอบ)' 'manycups'
#  'ISAO (อิซาโอะ)' 'The Oasis Spa' 'ก๋วยเตี๋ยวเนื้อตุ๋นท่าน้ำสาธุฯ'
#  'Sühring' 'Lookshin Anamai (ลูกชิ้น อนามัย)' 'Teppen (เท้ปเป้น)'
#  'The Oyster Bar' 'อุทยานเฉลิมกาญจนาภิเษก' 'OK Shabu Shabu'
#  'Kaizen Coffee Newold' 'The Commons (เดอะคอมม่อนส์)' 'ก๋วยเตี๋ยวนายแว่น'
#  'Octave Rooftop Lounge & Bar' 'Think Space B2S (ธิงค์สเปซ บีทูเอส)'
#  'Zong Ped Palow (ซ้งเป็ดพะโล้)' "Pho' 54 (เฝอ 54)" 'Ob Aroi (อบอร่อย)'
#  "PHO'54 (เฝอ'54)" 'Maria (มาเรีย)']

# %%
# Exploring the categories for feature extraction.
for i in df['venue.categories']:
    print(i)
# Out:
# [{'id': '4bf58dd8d48988d1e7931735', 'name': 'Jazz Club', 'pluralName': 'Jazz Clubs', 'shortName': 'Jazz Club', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52e81612bcbc57f1066b7a3e', 'name': 'Buddhist Temple', 'pluralName': 'Buddhist Temples', 'shortName': 'Buddhist Temple', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52e81612bcbc57f1066b7a14', 'name': 'Palace', 'pluralName': 'Palaces', 'shortName': 'Palace', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'Massage Studio', 'pluralName': 'Massage Studios', 'shortName': 'Massage Studio', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4eb1d80a4b900d56c88a45ff', 'name': 'Shrine', 'pluralName': 'Shrines', 'shortName': 'Shrine', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_shrine_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4eb1bea83b7b6f98df247e06', 'name': 'Factory', 'pluralName': 'Factories', 'shortName': 'Factory', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/factory_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d114951735', 'name': 'Bookstore', 'pluralName': 'Bookstores', 'shortName': 'Bookstore', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d12f951735', 'name': 'Resort', 'pluralName': 'Resorts', 'shortName': 'Resort', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d175941735', 'name': 'Gym / Fitness Center', 'pluralName': 'Gyms or Fitness Centers', 'shortName': 'Gym / Fitness', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'Massage Studio', 'pluralName': 'Massage Studios', 'shortName': 'Massage Studio', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '56aa371be4b08b9a8d573520', 'name': 'Tour Provider', 'pluralName': 'Tour Providers', 'shortName': 'Tour Provider', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4deefb944765f83613cdba6e', 'name': 'Historic Site', 'pluralName': 'Historic Sites', 'shortName': 'Historic Site', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d149941735', 'name': 'Thai Restaurant', 'pluralName': 'Thai Restaurants', 'shortName': 'Thai', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ed941735', 'name': 'Spa', 'pluralName': 'Spas', 'shortName': 'Spa', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '56aa371be4b08b9a8d573502', 'name': 'Som Tum Restaurant', 'pluralName': 'Som Tum Restaurants', 'shortName': 'Som Tum', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'Supermarket', 'pluralName': 'Supermarkets', 'shortName': 'Supermarket', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ee931735', 'name': 'Hostel', 'pluralName': 'Hostels', 'shortName': 'Hostel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4deefb944765f83613cdba6e', 'name': 'Historic Site', 'pluralName': 'Historic Sites', 'shortName': 'Historic Site', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ee931735', 'name': 'Hostel', 'pluralName': 'Hostels', 'shortName': 'Hostel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d16a941735', 'name': 'Bakery', 'pluralName': 'Bakeries', 'shortName': 'Bakery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1c9941735', 'name': 'Ice Cream Shop', 'pluralName': 'Ice Cream Shops', 'shortName': 'Ice Cream', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d0941735', 'name': 'Dessert Shop', 'pluralName': 'Dessert Shops', 'shortName': 'Desserts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d5941735', 'name': 'Hotel Bar', 'pluralName': 'Hotel Bars', 'shortName': 'Hotel Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d180941735', 'name': 'Multiplex', 'pluralName': 'Multiplexes', 'shortName': 'Cineplex', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d0941735', 'name': 'Dessert Shop', 'pluralName': 'Dessert Shops', 'shortName': 'Desserts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d149941735', 'name': 'Thai Restaurant', 'pluralName': 'Thai Restaurants', 'shortName': 'Thai', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d114951735', 'name': 'Bookstore', 'pluralName': 'Bookstores', 'shortName': 'Bookstore', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d149941735', 'name': 'Thai Restaurant', 'pluralName': 'Thai Restaurants', 'shortName': 'Thai', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d116941735', 'name': 'Bar', 'pluralName': 'Bars', 'shortName': 'Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '55a59af1e4b013909087cb03', 'name': 'Tonkatsu Restaurant', 'pluralName': 'Tonkatsu Restaurants', 'shortName': 'Tonkatsu', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1c4941735', 'name': 'Restaurant', 'pluralName': 'Restaurants', 'shortName': 'Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d3941735', 'name': 'Vegetarian / Vegan Restaurant', 'pluralName': 'Vegetarian / Vegan Restaurants', 'shortName': 'Vegetarian / Vegan', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d142941735', 'name': 'Asian Restaurant', 'pluralName': 'Asian Restaurants', 'shortName': 'Asian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d11e941735', 'name': 'Cocktail Bar', 'pluralName': 'Cocktail Bars', 'shortName': 'Cocktail', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d143941735', 'name': 'Breakfast Spot', 'pluralName': 'Breakfast Spots', 'shortName': 'Breakfast', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d12f941735', 'name': 'Library', 'pluralName': 'Libraries', 'shortName': 'Library', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d114951735', 'name': 'Bookstore', 'pluralName': 'Bookstores', 'shortName': 'Bookstore', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1f7941735', 'name': 'Flea Market', 'pluralName': 'Flea Markets', 'shortName': 'Flea Market', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '56aa371be4b08b9a8d573502', 'name': 'Som Tum Restaurant', 'pluralName': 'Som Tum Restaurants', 'shortName': 'Som Tum', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e2931735', 'name': 'Art Gallery', 'pluralName': 'Art Galleries', 'shortName': 'Art Gallery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d12f951735', 'name': 'Resort', 'pluralName': 'Resorts', 'shortName': 'Resort', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d16a941735', 'name': 'Bakery', 'pluralName': 'Bakeries', 'shortName': 'Bakery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4d954b06a243a5684965b473', 'name': 'Residential Building (Apartment / Condo)', 'pluralName': 'Residential Buildings (Apartments / Condos)', 'shortName': 'Residential', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ed941735', 'name': 'Spa', 'pluralName': 'Spas', 'shortName': 'Spa', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1df931735', 'name': 'BBQ Joint', 'pluralName': 'BBQ Joints', 'shortName': 'BBQ', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d149941735', 'name': 'Thai Restaurant', 'pluralName': 'Thai Restaurants', 'shortName': 'Thai', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'Supermarket', 'pluralName': 'Supermarkets', 'shortName': 'Supermarket', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e3941735', 'name': 'Surf Spot', 'pluralName': 'Surf Spots', 'shortName': 'Surf Spot', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/surfspot_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ff941735', 'name': 'Miscellaneous Shop', 'pluralName': 'Miscellaneous Shops', 'shortName': 'Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '53e510b7498ebcb1801b55d4', 'name': 'Night Market', 'pluralName': 'Night Markets', 'shortName': 'Night Market', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d142941735', 'name': 'Asian Restaurant', 'pluralName': 'Asian Restaurants', 'shortName': 'Asian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1c9941735', 'name': 'Ice Cream Shop', 'pluralName': 'Ice Cream Shops', 'shortName': 'Ice Cream', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ed941735', 'name': 'Spa', 'pluralName': 'Spas', 'shortName': 'Spa', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d10d941735', 'name': 'German Restaurant', 'pluralName': 'German Restaurants', 'shortName': 'German', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52e81612bcbc57f1066b7a3e', 'name': 'Buddhist Temple', 'pluralName': 'Buddhist Temples', 'shortName': 'Buddhist Temple', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52e81612bcbc57f1066b7a14', 'name': 'Palace', 'pluralName': 'Palaces', 'shortName': 'Palace', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'Massage Studio', 'pluralName': 'Massage Studios', 'shortName': 'Massage Studio', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4eb1d80a4b900d56c88a45ff', 'name': 'Shrine', 'pluralName': 'Shrines', 'shortName': 'Shrine', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_shrine_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4eb1bea83b7b6f98df247e06', 'name': 'Factory', 'pluralName': 'Factories', 'shortName': 'Factory', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/factory_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d114951735', 'name': 'Bookstore', 'pluralName': 'Bookstores', 'shortName': 'Bookstore', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d12f951735', 'name': 'Resort', 'pluralName': 'Resorts', 'shortName': 'Resort', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d175941735', 'name': 'Gym / Fitness Center', 'pluralName': 'Gyms or Fitness Centers', 'shortName': 'Gym / Fitness', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'Massage Studio', 'pluralName': 'Massage Studios', 'shortName': 'Massage Studio', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '56aa371be4b08b9a8d573520', 'name': 'Tour Provider', 'pluralName': 'Tour Providers', 'shortName': 'Tour Provider', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4deefb944765f83613cdba6e', 'name': 'Historic Site', 'pluralName': 'Historic Sites', 'shortName': 'Historic Site', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d149941735', 'name': 'Thai Restaurant', 'pluralName': 'Thai Restaurants', 'shortName': 'Thai', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ed941735', 'name': 'Spa', 'pluralName': 'Spas', 'shortName': 'Spa', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '56aa371be4b08b9a8d573502', 'name': 'Som Tum Restaurant', 'pluralName': 'Som Tum Restaurants', 'shortName': 'Som Tum', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'Supermarket', 'pluralName': 'Supermarkets', 'shortName': 'Supermarket', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ee931735', 'name': 'Hostel', 'pluralName': 'Hostels', 'shortName': 'Hostel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4deefb944765f83613cdba6e', 'name': 'Historic Site', 'pluralName': 'Historic Sites', 'shortName': 'Historic Site', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ee931735', 'name': 'Hostel', 'pluralName': 'Hostels', 'shortName': 'Hostel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d16a941735', 'name': 'Bakery', 'pluralName': 'Bakeries', 'shortName': 'Bakery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1c9941735', 'name': 'Ice Cream Shop', 'pluralName': 'Ice Cream Shops', 'shortName': 'Ice Cream', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d0941735', 'name': 'Dessert Shop', 'pluralName': 'Dessert Shops', 'shortName': 'Desserts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d5941735', 'name': 'Hotel Bar', 'pluralName': 'Hotel Bars', 'shortName': 'Hotel Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d180941735', 'name': 'Multiplex', 'pluralName': 'Multiplexes', 'shortName': 'Cineplex', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d0941735', 'name': 'Dessert Shop', 'pluralName': 'Dessert Shops', 'shortName': 'Desserts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d149941735', 'name': 'Thai Restaurant', 'pluralName': 'Thai Restaurants', 'shortName': 'Thai', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d114951735', 'name': 'Bookstore', 'pluralName': 'Bookstores', 'shortName': 'Bookstore', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d149941735', 'name': 'Thai Restaurant', 'pluralName': 'Thai Restaurants', 'shortName': 'Thai', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d116941735', 'name': 'Bar', 'pluralName': 'Bars', 'shortName': 'Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '55a59af1e4b013909087cb03', 'name': 'Tonkatsu Restaurant', 'pluralName': 'Tonkatsu Restaurants', 'shortName': 'Tonkatsu', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1c4941735', 'name': 'Restaurant', 'pluralName': 'Restaurants', 'shortName': 'Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d3941735', 'name': 'Vegetarian / Vegan Restaurant', 'pluralName': 'Vegetarian / Vegan Restaurants', 'shortName': 'Vegetarian / Vegan', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d142941735', 'name': 'Asian Restaurant', 'pluralName': 'Asian Restaurants', 'shortName': 'Asian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d11e941735', 'name': 'Cocktail Bar', 'pluralName': 'Cocktail Bars', 'shortName': 'Cocktail', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d143941735', 'name': 'Breakfast Spot', 'pluralName': 'Breakfast Spots', 'shortName': 'Breakfast', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d12f941735', 'name': 'Library', 'pluralName': 'Libraries', 'shortName': 'Library', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d114951735', 'name': 'Bookstore', 'pluralName': 'Bookstores', 'shortName': 'Bookstore', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1f7941735', 'name': 'Flea Market', 'pluralName': 'Flea Markets', 'shortName': 'Flea Market', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '56aa371be4b08b9a8d573502', 'name': 'Som Tum Restaurant', 'pluralName': 'Som Tum Restaurants', 'shortName': 'Som Tum', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e2931735', 'name': 'Art Gallery', 'pluralName': 'Art Galleries', 'shortName': 'Art Gallery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d12f951735', 'name': 'Resort', 'pluralName': 'Resorts', 'shortName': 'Resort', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d16a941735', 'name': 'Bakery', 'pluralName': 'Bakeries', 'shortName': 'Bakery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4d954b06a243a5684965b473', 'name': 'Residential Building (Apartment / Condo)', 'pluralName': 'Residential Buildings (Apartments / Condos)', 'shortName': 'Residential', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ed941735', 'name': 'Spa', 'pluralName': 'Spas', 'shortName': 'Spa', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1df931735', 'name': 'BBQ Joint', 'pluralName': 'BBQ Joints', 'shortName': 'BBQ', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d149941735', 'name': 'Thai Restaurant', 'pluralName': 'Thai Restaurants', 'shortName': 'Thai', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'Supermarket', 'pluralName': 'Supermarkets', 'shortName': 'Supermarket', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e3941735', 'name': 'Surf Spot', 'pluralName': 'Surf Spots', 'shortName': 'Surf Spot', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/surfspot_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ff941735', 'name': 'Miscellaneous Shop', 'pluralName': 'Miscellaneous Shops', 'shortName': 'Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '53e510b7498ebcb1801b55d4', 'name': 'Night Market', 'pluralName': 'Night Markets', 'shortName': 'Night Market', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d142941735', 'name': 'Asian Restaurant', 'pluralName': 'Asian Restaurants', 'shortName': 'Asian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1c9941735', 'name': 'Ice Cream Shop', 'pluralName': 'Ice Cream Shops', 'shortName': 'Ice Cream', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ed941735', 'name': 'Spa', 'pluralName': 'Spas', 'shortName': 'Spa', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d10d941735', 'name': 'German Restaurant', 'pluralName': 'German Restaurants', 'shortName': 'German', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ce941735', 'name': 'Seafood Restaurant', 'pluralName': 'Seafood Restaurants', 'shortName': 'Seafood', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52e81612bcbc57f1066b7a3e', 'name': 'Buddhist Temple', 'pluralName': 'Buddhist Temples', 'shortName': 'Buddhist Temple', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52e81612bcbc57f1066b7a14', 'name': 'Palace', 'pluralName': 'Palaces', 'shortName': 'Palace', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'Massage Studio', 'pluralName': 'Massage Studios', 'shortName': 'Massage Studio', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4eb1d80a4b900d56c88a45ff', 'name': 'Shrine', 'pluralName': 'Shrines', 'shortName': 'Shrine', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_shrine_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4eb1bea83b7b6f98df247e06', 'name': 'Factory', 'pluralName': 'Factories', 'shortName': 'Factory', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/factory_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d114951735', 'name': 'Bookstore', 'pluralName': 'Bookstores', 'shortName': 'Bookstore', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d12f951735', 'name': 'Resort', 'pluralName': 'Resorts', 'shortName': 'Resort', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_', 'suffix': '.png'}, 'primary': True}]
# ...
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1c4941735', 'name': 'Restaurant', 'pluralName': 'Restaurants', 'shortName': 'Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d3941735', 'name': 'Vegetarian / Vegan Restaurant', 'pluralName': 'Vegetarian / Vegan Restaurants', 'shortName': 'Vegetarian / Vegan', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d142941735', 'name': 'Asian Restaurant', 'pluralName': 'Asian Restaurants', 'shortName': 'Asian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d11e941735', 'name': 'Cocktail Bar', 'pluralName': 'Cocktail Bars', 'shortName': 'Cocktail', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d143941735', 'name': 'Breakfast Spot', 'pluralName': 'Breakfast Spots', 'shortName': 'Breakfast', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d12f941735', 'name': 'Library', 'pluralName': 'Libraries', 'shortName': 'Library', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d114951735', 'name': 'Bookstore', 'pluralName': 'Bookstores', 'shortName': 'Bookstore', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1f7941735', 'name': 'Flea Market', 'pluralName': 'Flea Markets', 'shortName': 'Flea Market', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '56aa371be4b08b9a8d573502', 'name': 'Som Tum Restaurant', 'pluralName': 'Som Tum Restaurants', 'shortName': 'Som Tum', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e2931735', 'name': 'Art Gallery', 'pluralName': 'Art Galleries', 'shortName': 'Art Gallery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d12f951735', 'name': 'Resort', 'pluralName': 'Resorts', 'shortName': 'Resort', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d16a941735', 'name': 'Bakery', 'pluralName': 'Bakeries', 'shortName': 'Bakery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4d954b06a243a5684965b473', 'name': 'Residential Building (Apartment / Condo)', 'pluralName': 'Residential Buildings (Apartments / Condos)', 'shortName': 'Residential', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ed941735', 'name': 'Spa', 'pluralName': 'Spas', 'shortName': 'Spa', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1df931735', 'name': 'BBQ Joint', 'pluralName': 'BBQ Joints', 'shortName': 'BBQ', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d149941735', 'name': 'Thai Restaurant', 'pluralName': 'Thai Restaurants', 'shortName': 'Thai', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'Supermarket', 'pluralName': 'Supermarkets', 'shortName': 'Supermarket', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e3941735', 'name': 'Surf Spot', 'pluralName': 'Surf Spots', 'shortName': 'Surf Spot', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/surfspot_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ff941735', 'name': 'Miscellaneous Shop', 'pluralName': 'Miscellaneous Shops', 'shortName': 'Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '53e510b7498ebcb1801b55d4', 'name': 'Night Market', 'pluralName': 'Night Markets', 'shortName': 'Night Market', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d142941735', 'name': 'Asian Restaurant', 'pluralName': 'Asian Restaurants', 'shortName': 'Asian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1c9941735', 'name': 'Ice Cream Shop', 'pluralName': 'Ice Cream Shops', 'shortName': 'Ice Cream', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ed941735', 'name': 'Spa', 'pluralName': 'Spas', 'shortName': 'Spa', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d10d941735', 'name': 'German Restaurant', 'pluralName': 'German Restaurants', 'shortName': 'German', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ce941735', 'name': 'Seafood Restaurant', 'pluralName': 'Seafood Restaurants', 'shortName': 'Seafood', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d163941735', 'name': 'Park', 'pluralName': 'Parks', 'shortName': 'Park', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '56aa371be4b08b9a8d573502', 'name': 'Som Tum Restaurant', 'pluralName': 'Som Tum Restaurants', 'shortName': 'Som Tum', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '56aa371be4b08b9a8d573502', 'name': 'Som Tum Restaurant', 'pluralName': 'Som Tum Restaurants', 'shortName': 'Som Tum', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '55a59bace4b013909087cb15', 'name': 'Shabu-Shabu Restaurant', 'pluralName': 'Shabu-Shabu Restaurants', 'shortName': 'Shabu-Shabu', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d5941735', 'name': 'Hotel Bar', 'pluralName': 'Hotel Bars', 'shortName': 'Hotel Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d114951735', 'name': 'Bookstore', 'pluralName': 'Bookstores', 'shortName': 'Bookstore', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1d0941735', 'name': 'Dessert Shop', 'pluralName': 'Dessert Shops', 'shortName': 'Desserts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d14a941735', 'name': 'Vietnamese Restaurant', 'pluralName': 'Vietnamese Restaurants', 'shortName': 'Vietnamese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1ce941735', 'name': 'Seafood Restaurant', 'pluralName': 'Seafood Restaurants', 'shortName': 'Seafood', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d14a941735', 'name': 'Vietnamese Restaurant', 'pluralName': 'Vietnamese Restaurants', 'shortName': 'Vietnamese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]

# %%
df['Category'] = df.apply(lambda row: row['venue.categories'][0]['name'], axis=1)
print(df.head())
df.Category.unique()
# Out:
#                                     venue.categories venue.location.city  \
# 0  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...              พระนคร
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...              พระนคร
# 2  [{'id': '52e81612bcbc57f1066b7a3e', 'name': 'B...              พระนคร
# 3  [{'id': '52e81612bcbc57f1066b7a14', 'name': 'P...              พระนคร
# 4  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...               ดุสิต
#
#    venue.location.lat  venue.location.lng  \
# 0           13.763043          100.498839
# 1           13.762308          100.493020
# 2           13.751735          100.492651
# 3           13.750105          100.490524
# 4           13.784805          100.512836
#
#                                           venue.name         Category
# 0                          Adhere the 13th Blues Bar        Jazz Club
# 1                                 Riva Surya Bangkok            Hotel
# 2  Temple of the Emerald Buddha (วัดพระศรีรัตนศาส...  Buddhist Temple
# 3  Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิต...           Palace
# 4                 Look Chin Sri Yan (ลูกชิ้นศรีย่าน)     Noodle House
# array(['Jazz Club', 'Hotel', 'Buddhist Temple', 'Palace', 'Noodle House',
#        'Massage Studio', 'Shrine', 'Coffee Shop', 'Factory', 'Bookstore',
#        'Park', 'Resort', 'Gym / Fitness Center', 'Japanese Restaurant',
#        'Tour Provider', 'Historic Site', 'Thai Restaurant', 'Spa',
#        'Som Tum Restaurant', 'Supermarket', 'Hostel', 'Bakery',
#        'Ice Cream Shop', 'Shopping Mall', 'Dessert Shop', 'Hotel Bar',
#        'Multiplex', 'Indian Restaurant', 'Bar', 'Tonkatsu Restaurant',
#        'Restaurant', 'Vegetarian / Vegan Restaurant', 'Asian Restaurant',
#        'Café', 'Cocktail Bar', 'Breakfast Spot', 'Library', 'Flea Market',
#        'Art Gallery', 'Residential Building (Apartment / Condo)',
#        'BBQ Joint', 'Surf Spot', 'Miscellaneous Shop', 'Night Market',
#        'Sushi Restaurant', 'German Restaurant', 'Seafood Restaurant',
#        'Shabu-Shabu Restaurant', 'Chinese Restaurant',
#        'Vietnamese Restaurant', 'Italian Restaurant'], dtype=object)

# %%
# Replace categories with something more similiar to each other.
def replace_category(df):
    print(df)
    cat = df['Category']
    if 'Restaurant' in cat or 'Joint' in cat or 'House' in cat or 'Place' in cat or 'Bar' in cat or 'Café' in cat or 'Pub' in cat:
        df.Category = 'Food'
    elif 'Hotel' in cat or 'Spa' in cat or 'Massage' in cat or 'Hostel' in cat:
        df.Category = 'Service'
    else:
        df.Category ='Attraction'
    return df

print(df)
df_new = df.apply(replace_category, axis=1)
df_new
# Out:
#                                        venue.categories venue.location.city  \
# 0     [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...              พระนคร
# 1     [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...              พระนคร
# 2     [{'id': '52e81612bcbc57f1066b7a3e', 'name': 'B...              พระนคร
# 3     [{'id': '52e81612bcbc57f1066b7a14', 'name': 'P...              พระนคร
# 4     [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...               ดุสิต
# 5     [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'M...     Chana Songkhram
# 6     [{'id': '4eb1d80a4b900d56c88a45ff', 'name': 'S...   ป้อมปราบศัตรูพ่าย
# 7     [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...              พระนคร
# 8     [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...          บางกอกน้อย
# 9     [{'id': '4eb1bea83b7b6f98df247e06', 'name': 'F...              พระนคร
# 10    [{'id': '4bf58dd8d48988d114951735', 'name': 'B...             ปทุมวัน
# 11    [{'id': '4bf58dd8d48988d163941735', 'name': 'P...          บางกอกน้อย
# 12    [{'id': '4bf58dd8d48988d12f951735', 'name': 'R...              พระนคร
# 13    [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...               ดุสิต
# 14    [{'id': '4bf58dd8d48988d175941735', 'name': 'G...             ปทุมวัน
# 15    [{'id': '4bf58dd8d48988d111941735', 'name': 'J...               พญาไท
# 16    [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'M...              พระนคร
# 17    [{'id': '56aa371be4b08b9a8d573520', 'name': 'T...              พระนคร
# 18    [{'id': '4deefb944765f83613cdba6e', 'name': 'H...          บางกอกใหญ่
# 19    [{'id': '4bf58dd8d48988d149941735', 'name': 'T...              พระนคร
# 20    [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...              พระนคร
# 21    [{'id': '56aa371be4b08b9a8d573502', 'name': 'S...             บางพลัด
# 22    [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...             ปทุมวัน
# 23    [{'id': '4bf58dd8d48988d1ee931735', 'name': 'H...              พระนคร
# 24    [{'id': '4bf58dd8d48988d111941735', 'name': 'J...             ปทุมวัน
# 25    [{'id': '4deefb944765f83613cdba6e', 'name': 'H...             ราชเทวี
# 26    [{'id': '4bf58dd8d48988d1ee931735', 'name': 'H...               พญาไท
# 27    [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...             ปทุมวัน
# 28    [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...          บางกอกน้อย
# 29    [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...             ปทุมวัน
# ...                                                 ...                 ...
# 1970  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...               วัฒนา
# 1971  [{'id': '53e510b7498ebcb1801b55d4', 'name': 'N...           Din Daeng
# 1972  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...               วัฒนา
# 1973  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...           บางคอแหลม
# 1974  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...             คลองเตย
# 1975  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...               วัฒนา
# 1976  [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...               วัฒนา
# 1977  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...             ยานนาวา
# 1978  [{'id': '4bf58dd8d48988d10d941735', 'name': 'G...             ยานนาวา
# 1979  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...            ห้วยขวาง
# 1980  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...               วัฒนา
# 1981  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...             Yannawa
# 1982  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...        เมืองนนทบุรี
# 1983  [{'id': '56aa371be4b08b9a8d573502', 'name': 'S...            ทวีวัฒนา
# 1984  [{'id': '56aa371be4b08b9a8d573502', 'name': 'S...        เมืองนนทบุรี
# 1985  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...             บางซื่อ
# 1986  [{'id': '55a59bace4b013909087cb15', 'name': 'S...               วัฒนา
# 1987  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...               วัฒนา
# 1988  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...               วัฒนา
# 1989  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...               วัฒนา
# 1990  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...             จตุจักร
# 1991  [{'id': '4bf58dd8d48988d1d5941735', 'name': 'H...               วัฒนา
# 1992  [{'id': '4bf58dd8d48988d114951735', 'name': 'B...            ลาดพร้าว
# 1993  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...               บางแค
# 1994  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...            ลาดพร้าว
# 1995  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...            ลาดพร้าว
# 1996  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...          วังทองหลาง
# 1997  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...            ลาดพร้าว
# 1998  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         บางขุนเทียน
# 1999  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...        เมืองนนทบุรี
#
#       venue.location.lat  venue.location.lng  \
# 0              13.763043          100.498839
# 1              13.762308          100.493020
# 2              13.751735          100.492651
# 3              13.750105          100.490524
# 4              13.784805          100.512836
# 5              13.762363          100.495126
# 6              13.744578          100.510755
# 7              13.740937          100.495394
# 8              13.759789          100.486097
# 9              13.720542          100.499507
# 10             13.745839          100.534951
# 11             13.772266          100.468441
# 12             13.723993          100.514241
# 13             13.781879          100.504775
# 14             13.739676          100.536097
# 15             13.779563          100.538591
# 16             13.746596          100.494100
# 17             13.730553          100.513835
# 18             13.743696          100.488930
# 19             13.744162          100.491700
# 20             13.759522          100.498694
# 21             13.779375          100.477465
# 22             13.746354          100.534550
# 23             13.755931          100.533678
# 24             13.746509          100.531974
# 25             13.768419          100.532756
# 26             13.776261          100.541744
# 27             13.734807          100.524340
# 28             13.751464          100.478605
# 29             13.748260          100.535074
# ...                  ...                 ...
# 1970           13.736770          100.584440
# 1971           13.766791          100.568827
# 1972           13.734906          100.587778
# 1973           13.685724          100.518524
# 1974           13.721023          100.569374
# 1975           13.734558          100.566417
# 1976           13.740833          100.568225
# 1977           13.677993          100.527887
# 1978           13.710749          100.545607
# 1979           13.747697          100.583404
# 1980           13.722948          100.583401
# 1981           13.701563          100.537315
# 1982           13.849820          100.481134
# 1983           13.767756          100.395465
# 1984           13.830266          100.480292
# 1985           13.841061          100.533853
# 1986           13.734662          100.577545
# 1987           13.740010          100.589747
# 1988           13.735056          100.582229
# 1989           13.734431          100.587621
# 1990           13.844133          100.568736
# 1991           13.723549          100.580519
# 1992           13.804555          100.614559
# 1993           13.713528          100.408106
# 1994           13.830590          100.592429
# 1995           13.822019          100.591708
# 1996           13.771796          100.608878
# 1997           13.815520          100.596351
# 1998           13.669379          100.451663
# 1999           13.867007          100.451483
#
#                                              venue.name  \
# 0                             Adhere the 13th Blues Bar
# 1                                    Riva Surya Bangkok
# 2     Temple of the Emerald Buddha (วัดพระศรีรัตนศาส...
# 3     Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิต...
# 4                    Look Chin Sri Yan (ลูกชิ้นศรีย่าน)
# 5                                     Massage In Garden
# 6                 Tai Hong Kong Shrine (ศาลเจ้าไต้ฮงกง)
# 7                                Starbucks (สตาร์บัคส์)
# 8                                Starbucks (สตาร์บัคส์)
# 9                                                ELF925
# 10                       Books Kinokuniya (คิโนะคูนิยะ)
# 11    สวนเฉลิมพระเกียรติ ๘๐ พรรษา พระบาทสมเด็จพระเจ้...
# 12                           Mandarin Oriental, Bangkok
# 13                                             The Siam
# 14                                    RBSC Fitness Club
# 15                                    Hanazen (ฮานะเซน)
# 16    Wat Pho Thai Traditional Medical and Massage S...
# 17                                        Co van Kessel
# 18                   Wat Arun Prang (พระปรางค์วัดอรุณฯ)
# 19    Supanniga Eating Room x Roots Coffee (ห้องทานข...
# 20                      Pai Spa (ปัยย์สปา บ้านรามบุตรี)
# 21                                 Ta Bun Tum (ตะบันตำ)
# 22                   Gourmet Market (กูร์เมต์ มาร์เก็ต)
# 23                                      In a Box Hostel
# 24                          Tonkatsu Wako (หมูทอด วาโก)
# 25                    Phya Thai Palace (พระราชวังพญาไท)
# 26                           The Yard (บ้านญาติ โฮสเทล)
# 27                               Rod Dee Det (รสดีเด็ด)
# 28                              Mont Nom Sod (มนต์นมสด)
# 29                         Siam Kempinski Hotel Bangkok
# ...                                                 ...
# 1970                                        Kenji's Lab
# 1971    Train Night Market Ratchada (ตลาดนัดรถไฟ รัชดา)
# 1972                                 Arunwan (อรุณวรรณ)
# 1973  Chaaloem Phrakiat Park (สวนสาธารณะเฉลิมพระเกีย...
# 1974                                           manycups
# 1975                                     ISAO (อิซาโอะ)
# 1976                                      The Oasis Spa
# 1977                     ก๋วยเตี๋ยวเนื้อตุ๋นท่าน้ำสาธุฯ
# 1978                                            Sühring
# 1979                   Lookshin Anamai (ลูกชิ้น อนามัย)
# 1980                                  Teppen (เท้ปเป้น)
# 1981                                     The Oyster Bar
# 1982                             อุทยานเฉลิมกาญจนาภิเษก
# 1983                            Baan Somtum (บ้านส้มตำ)
# 1984                            Baan Somtum (บ้านส้มตำ)
# 1985                             Starbucks (สตาร์บัคส์)
# 1986                                     OK Shabu Shabu
# 1987                               Kaizen Coffee Newold
# 1988                        The Commons (เดอะคอมม่อนส์)
# 1989                                  ก๋วยเตี๋ยวนายแว่น
# 1990                             Starbucks (สตาร์บัคส์)
# 1991                        Octave Rooftop Lounge & Bar
# 1992                Think Space B2S (ธิงค์สเปซ บีทูเอส)
# 1993                            After You (อาฟเตอร์ ยู)
# 1994                      Zong Ped Palow (ซ้งเป็ดพะโล้)
# 1995                                   Pho' 54 (เฝอ 54)
# 1996                                  Ob Aroi (อบอร่อย)
# 1997                                    PHO'54 (เฝอ'54)
# 1998                             Starbucks (สตาร์บัคส์)
# 1999                                     Maria (มาเรีย)
#
#                     Category
# 0                  Jazz Club
# 1                      Hotel
# 2            Buddhist Temple
# 3                     Palace
# 4               Noodle House
# 5             Massage Studio
# 6                     Shrine
# 7                Coffee Shop
# 8                Coffee Shop
# 9                    Factory
# 10                 Bookstore
# 11                      Park
# 12                    Resort
# 13                     Hotel
# 14      Gym / Fitness Center
# 15       Japanese Restaurant
# 16            Massage Studio
# 17             Tour Provider
# 18             Historic Site
# 19           Thai Restaurant
# 20                       Spa
# 21        Som Tum Restaurant
# 22               Supermarket
# 23                    Hostel
# 24       Japanese Restaurant
# 25             Historic Site
# 26                    Hostel
# 27              Noodle House
# 28                    Bakery
# 29                     Hotel
# ...                      ...
# 1970     Japanese Restaurant
# 1971            Night Market
# 1972        Asian Restaurant
# 1973                    Park
# 1974          Ice Cream Shop
# 1975        Sushi Restaurant
# 1976                     Spa
# 1977            Noodle House
# 1978       German Restaurant
# 1979            Noodle House
# 1980     Japanese Restaurant
# 1981      Seafood Restaurant
# 1982                    Park
# 1983      Som Tum Restaurant
# 1984      Som Tum Restaurant
# 1985             Coffee Shop
# 1986  Shabu-Shabu Restaurant
# 1987             Coffee Shop
# 1988           Shopping Mall
# 1989            Noodle House
# 1990             Coffee Shop
# 1991               Hotel Bar
# 1992               Bookstore
# 1993            Dessert Shop
# 1994      Chinese Restaurant
# 1995   Vietnamese Restaurant
# 1996      Seafood Restaurant
# 1997   Vietnamese Restaurant
# 1998             Coffee Shop
# 1999      Italian Restaurant
#
# [2000 rows x 6 columns]
# venue.categories       [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...
# venue.location.city                                               พระนคร
# venue.location.lat                                                13.763
# venue.location.lng                                               100.499
# venue.name                                     Adhere the 13th Blues Bar
# Category                                                       Jazz Club
# Name: 0, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...
# venue.location.city                                               พระนคร
# venue.location.lat                                                13.763
# venue.location.lng                                               100.499
# venue.name                                     Adhere the 13th Blues Bar
# Category                                                       Jazz Club
# Name: 0, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7623
# venue.location.lng                                               100.493
# venue.name                                            Riva Surya Bangkok
# Category                                                           Hotel
# Name: 1, dtype: object
# venue.categories       [{'id': '52e81612bcbc57f1066b7a3e', 'name': 'B...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7517
# venue.location.lng                                               100.493
# venue.name             Temple of the Emerald Buddha (วัดพระศรีรัตนศาส...
# Category                                                 Buddhist Temple
# Name: 2, dtype: object
# venue.categories       [{'id': '52e81612bcbc57f1066b7a14', 'name': 'P...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7501
# venue.location.lng                                               100.491
# venue.name             Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิต...
# Category                                                          Palace
# Name: 3, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...
# venue.location.city                                                ดุสิต
# venue.location.lat                                               13.7848
# venue.location.lng                                               100.513
# venue.name                            Look Chin Sri Yan (ลูกชิ้นศรีย่าน)
# Category                                                    Noodle House
# Name: 4, dtype: object
# venue.categories       [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'M...
# venue.location.city                                      Chana Songkhram
# venue.location.lat                                               13.7624
# venue.location.lng                                               100.495
# venue.name                                             Massage In Garden
# Category                                                  Massage Studio
# Name: 5, dtype: object
# venue.categories       [{'id': '4eb1d80a4b900d56c88a45ff', 'name': 'S...
# venue.location.city                                    ป้อมปราบศัตรูพ่าย
# venue.location.lat                                               13.7446
# venue.location.lng                                               100.511
# venue.name                         Tai Hong Kong Shrine (ศาลเจ้าไต้ฮงกง)
# Category                                                          Shrine
# Name: 6, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7409
# venue.location.lng                                               100.495
# venue.name                                        Starbucks (สตาร์บัคส์)
# Category                                                     Coffee Shop
# Name: 7, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# venue.location.city                                           บางกอกน้อย
# venue.location.lat                                               13.7598
# venue.location.lng                                               100.486
# venue.name                                        Starbucks (สตาร์บัคส์)
# Category                                                     Coffee Shop
# Name: 8, dtype: object
# venue.categories       [{'id': '4eb1bea83b7b6f98df247e06', 'name': 'F...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7205
# venue.location.lng                                                 100.5
# venue.name                                                        ELF925
# Category                                                         Factory
# Name: 9, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d114951735', 'name': 'B...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7458
# venue.location.lng                                               100.535
# venue.name                                Books Kinokuniya (คิโนะคูนิยะ)
# Category                                                       Bookstore
# Name: 10, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# venue.location.city                                           บางกอกน้อย
# venue.location.lat                                               13.7723
# venue.location.lng                                               100.468
# venue.name             สวนเฉลิมพระเกียรติ ๘๐ พรรษา พระบาทสมเด็จพระเจ้...
# Category                                                            Park
# Name: 11, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d12f951735', 'name': 'R...
# venue.location.city                                               พระนคร
# venue.location.lat                                                13.724
# venue.location.lng                                               100.514
# venue.name                                    Mandarin Oriental, Bangkok
# Category                                                          Resort
# Name: 12, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                                ดุสิต
# venue.location.lat                                               13.7819
# venue.location.lng                                               100.505
# venue.name                                                      The Siam
# Category                                                           Hotel
# Name: 13, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7397
# venue.location.lng                                               100.536
# venue.name                                             RBSC Fitness Club
# Category                                            Gym / Fitness Center
# Name: 14, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# venue.location.city                                                พญาไท
# venue.location.lat                                               13.7796
# venue.location.lng                                               100.539
# venue.name                                             Hanazen (ฮานะเซน)
# Category                                             Japanese Restaurant
# Name: 15, dtype: object
# venue.categories       [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'M...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7466
# venue.location.lng                                               100.494
# venue.name             Wat Pho Thai Traditional Medical and Massage S...
# Category                                                  Massage Studio
# Name: 16, dtype: object
# venue.categories       [{'id': '56aa371be4b08b9a8d573520', 'name': 'T...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7306
# venue.location.lng                                               100.514
# venue.name                                                 Co van Kessel
# Category                                                   Tour Provider
# Name: 17, dtype: object
# venue.categories       [{'id': '4deefb944765f83613cdba6e', 'name': 'H...
# venue.location.city                                           บางกอกใหญ่
# venue.location.lat                                               13.7437
# venue.location.lng                                               100.489
# venue.name                            Wat Arun Prang (พระปรางค์วัดอรุณฯ)
# Category                                                   Historic Site
# Name: 18, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7442
# venue.location.lng                                               100.492
# venue.name             Supanniga Eating Room x Roots Coffee (ห้องทานข...
# Category                                                 Thai Restaurant
# Name: 19, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7595
# venue.location.lng                                               100.499
# venue.name                               Pai Spa (ปัยย์สปา บ้านรามบุตรี)
# Category                                                             Spa
# Name: 20, dtype: object
# venue.categories       [{'id': '56aa371be4b08b9a8d573502', 'name': 'S...
# venue.location.city                                              บางพลัด
# venue.location.lat                                               13.7794
# venue.location.lng                                               100.477
# venue.name                                          Ta Bun Tum (ตะบันตำ)
# Category                                              Som Tum Restaurant
# Name: 21, dtype: object
# venue.categories       [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7464
# venue.location.lng                                               100.535
# venue.name                            Gourmet Market (กูร์เมต์ มาร์เก็ต)
# Category                                                     Supermarket
# Name: 22, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1ee931735', 'name': 'H...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7559
# venue.location.lng                                               100.534
# venue.name                                               In a Box Hostel
# Category                                                          Hostel
# Name: 23, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7465
# venue.location.lng                                               100.532
# venue.name                                   Tonkatsu Wako (หมูทอด วาโก)
# Category                                             Japanese Restaurant
# Name: 24, dtype: object
# venue.categories       [{'id': '4deefb944765f83613cdba6e', 'name': 'H...
# venue.location.city                                              ราชเทวี
# venue.location.lat                                               13.7684
# venue.location.lng                                               100.533
# venue.name                             Phya Thai Palace (พระราชวังพญาไท)
# Category                                                   Historic Site
# Name: 25, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1ee931735', 'name': 'H...
# venue.location.city                                                พญาไท
# venue.location.lat                                               13.7763
# venue.location.lng                                               100.542
# venue.name                                    The Yard (บ้านญาติ โฮสเทล)
# Category                                                          Hostel
# Name: 26, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7348
# venue.location.lng                                               100.524
# venue.name                                        Rod Dee Det (รสดีเด็ด)
# Category                                                    Noodle House
# Name: 27, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# venue.location.city                                           บางกอกน้อย
# venue.location.lat                                               13.7515
# venue.location.lng                                               100.479
# venue.name                                       Mont Nom Sod (มนต์นมสด)
# Category                                                          Bakery
# Name: 28, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7483
# venue.location.lng                                               100.535
# venue.name                                  Siam Kempinski Hotel Bangkok
# Category                                                           Hotel
# Name: 29, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7518
# venue.location.lng                                               100.498
# venue.name                  Nattaporn Ice cream (นัฐพร ไอศครีมกะทิสดแท้)
# Category                                                  Ice Cream Shop
# Name: 30, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                                13.747
# venue.location.lng                                               100.535
# venue.name                                    Siam Paragon (สยามพารากอน)
# Category                                                   Shopping Mall
# Name: 31, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7442
# venue.location.lng                                               100.534
# venue.name                                       After You (อาฟเตอร์ ยู)
# Category                                                    Dessert Shop
# Name: 32, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1d5941735', 'name': 'H...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7241
# venue.location.lng                                               100.514
# venue.name                                                The Bamboo Bar
# Category                                                       Hotel Bar
# Name: 33, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7466
# venue.location.lng                                               100.539
# venue.name                                 centralwOrld (เซ็นทรัลเวิลด์)
# Category                                                   Shopping Mall
# Name: 34, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d180941735', 'name': 'M...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7459
# venue.location.lng                                               100.535
# venue.name                        Paragon Cineplex (พารากอน ซีนีเพล็กซ์)
# Category                                                       Multiplex
# Name: 35, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7468
# venue.location.lng                                               100.534
# venue.name                                       After You (อาฟเตอร์ ยู)
# Category                                                    Dessert Shop
# Name: 36, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7341
# venue.location.lng                                               100.528
# venue.name                                                  สุกี้สามย่าน
# Category                                                 Thai Restaurant
# Name: 37, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                              คลองสาน
# venue.location.lat                                                13.723
# venue.location.lng                                               100.511
# venue.name                                         The Peninsula Bangkok
# Category                                                           Hotel
# Name: 38, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                               พระนคร
# venue.location.lat                                                13.722
# venue.location.lng                                               100.529
# venue.name                                                     W Bangkok
# Category                                                           Hotel
# Name: 39, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d114951735', 'name': 'B...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7472
# venue.location.lng                                                100.54
# venue.name                                Books Kinokuniya (คิโนะคูนิยะ)
# Category                                                       Bookstore
# Name: 40, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# venue.location.city                                              บางพลัด
# venue.location.lat                                               13.7907
# venue.location.lng                                                100.49
# venue.name                                                     ครัวในซอย
# Category                                                 Thai Restaurant
# Name: 41, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...
# venue.location.city                                              คลองสาน
# venue.location.lat                                               13.7177
# venue.location.lng                                               100.508
# venue.name                                                   Indian Food
# Category                                               Indian Restaurant
# Name: 42, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                                13.731
# venue.location.lng                                               100.542
# venue.name                                    Lumphini Park (สวนลุมพินี)
# Category                                                            Park
# Name: 43, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                               บางรัก
# venue.location.lat                                               13.7263
# venue.location.lng                                               100.543
# venue.name                                            SO Sofitel Bangkok
# Category                                                           Hotel
# Name: 44, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...
# venue.location.city                                            บางคอแหลม
# venue.location.lat                                               13.7091
# venue.location.lng                                               100.514
# venue.name                           Kuayjup Mr. Jo (ก๋วยจั๊บมิสเตอร์โจ)
# Category                                                    Noodle House
# Name: 45, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7461
# venue.location.lng                                               100.533
# venue.name                                   Siam Center (สยามเซ็นเตอร์)
# Category                                                   Shopping Mall
# Name: 46, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d116941735', 'name': 'B...
# venue.location.city                                               บางรัก
# venue.location.lat                                               13.7224
# venue.location.lng                                               100.514
# venue.name                                                    Jack's Bar
# Category                                                             Bar
# Name: 47, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7406
# venue.location.lng                                               100.542
# venue.name                                                Hansar Bangkok
# Category                                                           Hotel
# Name: 48, dtype: object
# venue.categories       [{'id': '55a59af1e4b013909087cb03', 'name': 'T...
# venue.location.city                                               บางรัก
# venue.location.lat                                                13.729
# venue.location.lng                                                100.53
# venue.name                                         Katsu-Shin (คัสซึชิน)
# Category                                             Tonkatsu Restaurant
# Name: 49, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# venue.location.city                                              ราชเทวี
# venue.location.lat                                               13.7626
# venue.location.lng                                               100.541
# venue.name                                 Suan Santi Phap (สวนสันติภาพ)
# Category                                                            Park
# Name: 50, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7399
# venue.location.lng                                                100.54
# venue.name                    The St. Regis Bangkok (โรงแรมเซนต์รีจิสต์)
# Category                                                           Hotel
# Name: 51, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...
# venue.location.city                                              คลองสาน
# venue.location.lat                                               13.7268
# venue.location.lng                                                100.51
# venue.name                                          ICONSIAM (ไอคอนสยาม)
# Category                                                   Shopping Mall
# Name: 52, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                               พระนคร
# venue.location.lat                                                 13.73
# venue.location.lng                                                100.53
# venue.name                                           Le Méridien Bangkok
# Category                                                           Hotel
# Name: 53, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7355
# venue.location.lng                                               100.546
# venue.name                                        Starbucks (สตาร์บัคส์)
# Category                                                     Coffee Shop
# Name: 54, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                               บางรัก
# venue.location.lat                                               13.7191
# venue.location.lng                                               100.522
# venue.name                                    Eastin Grand Hotel Sathorn
# Category                                                           Hotel
# Name: 55, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7436
# venue.location.lng                                                100.54
# venue.name                                    Grand Hyatt Erawan Bangkok
# Category                                                           Hotel
# Name: 56, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...
# venue.location.city                                                วัฒนา
# venue.location.lat                                               13.7361
# venue.location.lng                                               100.562
# venue.name                                                       indulge
# Category                                                      Restaurant
# Name: 57, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1d3941735', 'name': 'V...
# venue.location.city                                                วัฒนา
# venue.location.lat                                               13.7479
# venue.location.lng                                               100.552
# venue.name                                                      Na Aroon
# Category                                   Vegetarian / Vegan Restaurant
# Name: 58, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d142941735', 'name': 'A...
# venue.location.city                                               ธนบุรี
# venue.location.lat                                               13.7035
# venue.location.lng                                               100.485
# venue.name                                      Koa Chun Huad (กอชุนฮวด)
# Category                                                Asian Restaurant
# Name: 59, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...
# venue.location.city                                               บางรัก
# venue.location.lat                                               13.7217
# venue.location.lng                                               100.524
# venue.name                                                  Luka (ลูก้า)
# Category                                                            Café
# Name: 60, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# venue.location.city                                              จตุจักร
# venue.location.lat                                               13.8159
# venue.location.lng                                               100.554
# venue.name             Vachirabenjatas Park (Rot Fai Park) (สวนวชิรเบ...
# Category                                                            Park
# Name: 61, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                                 สาทร
# venue.location.lat                                               13.7235
# venue.location.lng                                               100.541
# venue.name                                         The Sukhothai Bangkok
# Category                                                           Hotel
# Name: 62, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d11e941735', 'name': 'C...
# venue.location.city                                                วัฒนา
# venue.location.lat                                               13.7456
# venue.location.lng                                               100.556
# venue.name                                                 Havana Social
# Category                                                    Cocktail Bar
# Name: 63, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d143941735', 'name': 'B...
# venue.location.city                                          สัมพันธวงศ์
# venue.location.lat                                               13.7373
# venue.location.lng                                               100.514
# venue.name                                   โจ๊กตลาดน้อย (เจ๊หมวยเกี้ย)
# Category                                                  Breakfast Spot
# Name: 64, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                               ธนบุรี
# venue.location.lat                                               13.7043
# venue.location.lng                                               100.492
# venue.name             Anantara Bangkok Riverside Spa & Resort (โรงแร...
# Category                                                           Hotel
# Name: 65, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...
# venue.location.city                                              จตุจักร
# venue.location.lat                                               13.8169
# venue.location.lng                                               100.556
# venue.name             หอจดหมายเหตุพุทธทาส อินทปัญโญ (BIA) Buddhadasa...
# Category                                                         Library
# Name: 66, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# venue.location.city                                              ปทุมวัน
# venue.location.lat                                               13.7329
# venue.location.lng                                               100.536
# venue.name                             Pacamara Boutique Coffee Roasters
# Category                                                     Coffee Shop
# Name: 67, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.7376
# venue.location.lng                                               100.559
# venue.name                             Sheraton Grande Sukhumvit Bangkok
# Category                                                           Hotel
# Name: 68, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d114951735', 'name': 'B...
# venue.location.city                                                วัฒนา
# venue.location.lat                                               13.7309
# venue.location.lng                                                100.57
# venue.name                                Books Kinokuniya (คิโนะคูนิยะ)
# Category                                                       Bookstore
# Name: 69, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1f7941735', 'name': 'F...
# venue.location.city                                              จตุจักร
# venue.location.lat                                                  13.8
# venue.location.lng                                               100.551
# venue.name                     Chatuchak Weekend Market (ตลาดนัดจตุจักร)
# Category                                                     Flea Market
# Name: 70, dtype: object
# venue.categories       [{'id': '56aa371be4b08b9a8d573502', 'name': 'S...
# venue.location.city                                               บางรัก
# venue.location.lat                                               13.7206
# venue.location.lng                                               100.521
# venue.name                                       Baan Somtum (บ้านส้มตำ)
# Category                                              Som Tum Restaurant
# Name: 71, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...
# venue.location.city                                               พระนคร
# venue.location.lat                                               13.8022
# venue.location.lng                                               100.552
# venue.name                            Chatuchak Market Section7 Art Zone
# Category                                                     Art Gallery
# Name: 72, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# venue.location.city                                              จตุจักร
# venue.location.lat                                               13.8067
# venue.location.lng                                               100.552
# ...
# Name: 1991, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d114951735', 'name': 'B...
# venue.location.city                                             ลาดพร้าว
# venue.location.lat                                               13.8046
# venue.location.lng                                               100.615
# venue.name                           Think Space B2S (ธิงค์สเปซ บีทูเอส)
# Category                                                       Bookstore
# Name: 1992, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...
# venue.location.city                                                บางแค
# venue.location.lat                                               13.7135
# venue.location.lng                                               100.408
# venue.name                                       After You (อาฟเตอร์ ยู)
# Category                                                    Dessert Shop
# Name: 1993, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d145941735', 'name': 'C...
# venue.location.city                                             ลาดพร้าว
# venue.location.lat                                               13.8306
# venue.location.lng                                               100.592
# venue.name                                 Zong Ped Palow (ซ้งเป็ดพะโล้)
# Category                                              Chinese Restaurant
# Name: 1994, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...
# venue.location.city                                             ลาดพร้าว
# venue.location.lat                                                13.822
# venue.location.lng                                               100.592
# venue.name                                              Pho' 54 (เฝอ 54)
# Category                                           Vietnamese Restaurant
# Name: 1995, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...
# venue.location.city                                           วังทองหลาง
# venue.location.lat                                               13.7718
# venue.location.lng                                               100.609
# venue.name                                             Ob Aroi (อบอร่อย)
# Category                                              Seafood Restaurant
# Name: 1996, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...
# venue.location.city                                             ลาดพร้าว
# venue.location.lat                                               13.8155
# venue.location.lng                                               100.596
# venue.name                                               PHO'54 (เฝอ'54)
# Category                                           Vietnamese Restaurant
# Name: 1997, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# venue.location.city                                          บางขุนเทียน
# venue.location.lat                                               13.6694
# venue.location.lng                                               100.452
# venue.name                                        Starbucks (สตาร์บัคส์)
# Category                                                     Coffee Shop
# Name: 1998, dtype: object
# venue.categories       [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# venue.location.city                                         เมืองนนทบุรี
# venue.location.lat                                                13.867
# venue.location.lng                                               100.451
# venue.name                                                Maria (มาเรีย)
# Category                                              Italian Restaurant
# Name: 1999, dtype: object
#                                        venue.categories venue.location.city  \
# 0     [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...              พระนคร
# 1     [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...              พระนคร
# 2     [{'id': '52e81612bcbc57f1066b7a3e', 'name': 'B...              พระนคร
# 3     [{'id': '52e81612bcbc57f1066b7a14', 'name': 'P...              พระนคร
# 4     [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...               ดุสิต
# 5     [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'M...     Chana Songkhram
# 6     [{'id': '4eb1d80a4b900d56c88a45ff', 'name': 'S...   ป้อมปราบศัตรูพ่าย
# 7     [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...              พระนคร
# 8     [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...          บางกอกน้อย
# 9     [{'id': '4eb1bea83b7b6f98df247e06', 'name': 'F...              พระนคร
# 10    [{'id': '4bf58dd8d48988d114951735', 'name': 'B...             ปทุมวัน
# 11    [{'id': '4bf58dd8d48988d163941735', 'name': 'P...          บางกอกน้อย
# 12    [{'id': '4bf58dd8d48988d12f951735', 'name': 'R...              พระนคร
# 13    [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...               ดุสิต
# 14    [{'id': '4bf58dd8d48988d175941735', 'name': 'G...             ปทุมวัน
# 15    [{'id': '4bf58dd8d48988d111941735', 'name': 'J...               พญาไท
# 16    [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'M...              พระนคร
# 17    [{'id': '56aa371be4b08b9a8d573520', 'name': 'T...              พระนคร
# 18    [{'id': '4deefb944765f83613cdba6e', 'name': 'H...          บางกอกใหญ่
# 19    [{'id': '4bf58dd8d48988d149941735', 'name': 'T...              พระนคร
# 20    [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...              พระนคร
# 21    [{'id': '56aa371be4b08b9a8d573502', 'name': 'S...             บางพลัด
# 22    [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...             ปทุมวัน
# 23    [{'id': '4bf58dd8d48988d1ee931735', 'name': 'H...              พระนคร
# 24    [{'id': '4bf58dd8d48988d111941735', 'name': 'J...             ปทุมวัน
# 25    [{'id': '4deefb944765f83613cdba6e', 'name': 'H...             ราชเทวี
# 26    [{'id': '4bf58dd8d48988d1ee931735', 'name': 'H...               พญาไท
# 27    [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...             ปทุมวัน
# 28    [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...          บางกอกน้อย
# 29    [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...             ปทุมวัน
# ...                                                 ...                 ...
# 1970  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...               วัฒนา
# 1971  [{'id': '53e510b7498ebcb1801b55d4', 'name': 'N...           Din Daeng
# 1972  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...               วัฒนา
# 1973  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...           บางคอแหลม
# 1974  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...             คลองเตย
# 1975  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...               วัฒนา
# 1976  [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...               วัฒนา
# 1977  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...             ยานนาวา
# 1978  [{'id': '4bf58dd8d48988d10d941735', 'name': 'G...             ยานนาวา
# 1979  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...            ห้วยขวาง
# 1980  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...               วัฒนา
# 1981  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...             Yannawa
# 1982  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...        เมืองนนทบุรี
# 1983  [{'id': '56aa371be4b08b9a8d573502', 'name': 'S...            ทวีวัฒนา
# 1984  [{'id': '56aa371be4b08b9a8d573502', 'name': 'S...        เมืองนนทบุรี
# 1985  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...             บางซื่อ
# 1986  [{'id': '55a59bace4b013909087cb15', 'name': 'S...               วัฒนา
# 1987  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...               วัฒนา
# 1988  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...               วัฒนา
# 1989  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...               วัฒนา
# 1990  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...             จตุจักร
# 1991  [{'id': '4bf58dd8d48988d1d5941735', 'name': 'H...               วัฒนา
# 1992  [{'id': '4bf58dd8d48988d114951735', 'name': 'B...            ลาดพร้าว
# 1993  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...               บางแค
# 1994  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...            ลาดพร้าว
# 1995  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...            ลาดพร้าว
# 1996  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...          วังทองหลาง
# 1997  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...            ลาดพร้าว
# 1998  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         บางขุนเทียน
# 1999  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...        เมืองนนทบุรี
#
#       venue.location.lat  venue.location.lng  \
# 0              13.763043          100.498839
# 1              13.762308          100.493020
# 2              13.751735          100.492651
# 3              13.750105          100.490524
# 4              13.784805          100.512836
# 5              13.762363          100.495126
# 6              13.744578          100.510755
# 7              13.740937          100.495394
# 8              13.759789          100.486097
# 9              13.720542          100.499507
# 10             13.745839          100.534951
# 11             13.772266          100.468441
# 12             13.723993          100.514241
# 13             13.781879          100.504775
# 14             13.739676          100.536097
# 15             13.779563          100.538591
# 16             13.746596          100.494100
# 17             13.730553          100.513835
# 18             13.743696          100.488930
# 19             13.744162          100.491700
# 20             13.759522          100.498694
# 21             13.779375          100.477465
# 22             13.746354          100.534550
# 23             13.755931          100.533678
# 24             13.746509          100.531974
# 25             13.768419          100.532756
# 26             13.776261          100.541744
# 27             13.734807          100.524340
# 28             13.751464          100.478605
# 29             13.748260          100.535074
# ...                  ...                 ...
# 1970           13.736770          100.584440
# 1971           13.766791          100.568827
# 1972           13.734906          100.587778
# 1973           13.685724          100.518524
# 1974           13.721023          100.569374
# 1975           13.734558          100.566417
# 1976           13.740833          100.568225
# 1977           13.677993          100.527887
# 1978           13.710749          100.545607
# 1979           13.747697          100.583404
# 1980           13.722948          100.583401
# 1981           13.701563          100.537315
# 1982           13.849820          100.481134
# 1983           13.767756          100.395465
# 1984           13.830266          100.480292
# 1985           13.841061          100.533853
# 1986           13.734662          100.577545
# 1987           13.740010          100.589747
# 1988           13.735056          100.582229
# 1989           13.734431          100.587621
# 1990           13.844133          100.568736
# 1991           13.723549          100.580519
# 1992           13.804555          100.614559
# 1993           13.713528          100.408106
# 1994           13.830590          100.592429
# 1995           13.822019          100.591708
# 1996           13.771796          100.608878
# 1997           13.815520          100.596351
# 1998           13.669379          100.451663
# 1999           13.867007          100.451483
#
#                                              venue.name    Category
# 0                             Adhere the 13th Blues Bar  Attraction
# 1                                    Riva Surya Bangkok     Service
# 2     Temple of the Emerald Buddha (วัดพระศรีรัตนศาส...  Attraction
# 3     Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิต...  Attraction
# 4                    Look Chin Sri Yan (ลูกชิ้นศรีย่าน)        Food
# 5                                     Massage In Garden     Service
# 6                 Tai Hong Kong Shrine (ศาลเจ้าไต้ฮงกง)  Attraction
# 7                                Starbucks (สตาร์บัคส์)  Attraction
# 8                                Starbucks (สตาร์บัคส์)  Attraction
# 9                                                ELF925  Attraction
# 10                       Books Kinokuniya (คิโนะคูนิยะ)  Attraction
# 11    สวนเฉลิมพระเกียรติ ๘๐ พรรษา พระบาทสมเด็จพระเจ้...  Attraction
# 12                           Mandarin Oriental, Bangkok  Attraction
# 13                                             The Siam     Service
# 14                                    RBSC Fitness Club  Attraction
# 15                                    Hanazen (ฮานะเซน)        Food
# 16    Wat Pho Thai Traditional Medical and Massage S...     Service
# 17                                        Co van Kessel  Attraction
# 18                   Wat Arun Prang (พระปรางค์วัดอรุณฯ)  Attraction
# 19    Supanniga Eating Room x Roots Coffee (ห้องทานข...        Food
# 20                      Pai Spa (ปัยย์สปา บ้านรามบุตรี)     Service
# 21                                 Ta Bun Tum (ตะบันตำ)        Food
# 22                   Gourmet Market (กูร์เมต์ มาร์เก็ต)  Attraction
# 23                                      In a Box Hostel     Service
# 24                          Tonkatsu Wako (หมูทอด วาโก)        Food
# 25                    Phya Thai Palace (พระราชวังพญาไท)  Attraction
# 26                           The Yard (บ้านญาติ โฮสเทล)     Service
# 27                               Rod Dee Det (รสดีเด็ด)        Food
# 28                              Mont Nom Sod (มนต์นมสด)  Attraction
# 29                         Siam Kempinski Hotel Bangkok     Service
# ...                                                 ...         ...
# 1970                                        Kenji's Lab        Food
# 1971    Train Night Market Ratchada (ตลาดนัดรถไฟ รัชดา)  Attraction
# 1972                                 Arunwan (อรุณวรรณ)        Food
# 1973  Chaaloem Phrakiat Park (สวนสาธารณะเฉลิมพระเกีย...  Attraction
# 1974                                           manycups  Attraction
# 1975                                     ISAO (อิซาโอะ)        Food
# 1976                                      The Oasis Spa     Service
# 1977                     ก๋วยเตี๋ยวเนื้อตุ๋นท่าน้ำสาธุฯ        Food
# 1978                                            Sühring        Food
# 1979                   Lookshin Anamai (ลูกชิ้น อนามัย)        Food
# 1980                                  Teppen (เท้ปเป้น)        Food
# 1981                                     The Oyster Bar        Food
# 1982                             อุทยานเฉลิมกาญจนาภิเษก  Attraction
# 1983                            Baan Somtum (บ้านส้มตำ)        Food
# 1984                            Baan Somtum (บ้านส้มตำ)        Food
# 1985                             Starbucks (สตาร์บัคส์)  Attraction
# 1986                                     OK Shabu Shabu        Food
# 1987                               Kaizen Coffee Newold  Attraction
# 1988                        The Commons (เดอะคอมม่อนส์)  Attraction
# 1989                                  ก๋วยเตี๋ยวนายแว่น        Food
# 1990                             Starbucks (สตาร์บัคส์)  Attraction
# 1991                        Octave Rooftop Lounge & Bar        Food
# 1992                Think Space B2S (ธิงค์สเปซ บีทูเอส)  Attraction
# 1993                            After You (อาฟเตอร์ ยู)  Attraction
# 1994                      Zong Ped Palow (ซ้งเป็ดพะโล้)        Food
# 1995                                   Pho' 54 (เฝอ 54)        Food
# 1996                                  Ob Aroi (อบอร่อย)        Food
# 1997                                    PHO'54 (เฝอ'54)        Food
# 1998                             Starbucks (สตาร์บัคส์)  Attraction
# 1999                                     Maria (มาเรีย)        Food
#
# [2000 rows x 6 columns]

# %%
# Lets create numeric categories for the city.
data = pd.concat([df_new, pd.get_dummies(df_new['Category'])], axis=1)
data.shape
# Out:
# (2000, 9)

# %%
# Grabbing features we want and renaming for convenience.
data.columns = ['venue.categories', 'venue.location.city', 'Latitude', 'Longitude', 'Venue_Name', 'Category', 'Attraction', 'Food', 'Service']
data_columns = data.columns
print(data_columns)
df_final = data[data_columns[2:]].set_index('Venue_Name')
df_final.head()
# Out:
# Index(['venue.categories', 'venue.location.city', 'Latitude', 'Longitude',
#        'Venue_Name', 'Category', 'Attraction', 'Food', 'Service'],
#       dtype='object')
#                                                      Latitude   Longitude  \
# Venue_Name
# Adhere the 13th Blues Bar                           13.763043  100.498839
# Riva Surya Bangkok                                  13.762308  100.493020
# Temple of the Emerald Buddha (วัดพระศรีรัตนศาสด...  13.751735  100.492651
# Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตม...  13.750105  100.490524
# Look Chin Sri Yan (ลูกชิ้นศรีย่าน)                  13.784805  100.512836
#
#                                                       Category  Attraction  \
# Venue_Name
# Adhere the 13th Blues Bar                           Attraction           1
# Riva Surya Bangkok                                     Service           0
# Temple of the Emerald Buddha (วัดพระศรีรัตนศาสด...  Attraction           1
# Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตม...  Attraction           1
# Look Chin Sri Yan (ลูกชิ้นศรีย่าน)                        Food           0
#
#                                                     Food  Service
# Venue_Name
# Adhere the 13th Blues Bar                              0        0
# Riva Surya Bangkok                                     0        1
# Temple of the Emerald Buddha (วัดพระศรีรัตนศาสด...     0        0
# Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตม...     0        0
# Look Chin Sri Yan (ลูกชิ้นศรีย่าน)                     1        0

# %%
df_final.drop_duplicates()
# Out:
#                                                      Latitude   Longitude  \
# Venue_Name
# Adhere the 13th Blues Bar                           13.763043  100.498839
# Riva Surya Bangkok                                  13.762308  100.493020
# Temple of the Emerald Buddha (วัดพระศรีรัตนศาสด...  13.751735  100.492651
# Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตม...  13.750105  100.490524
# Look Chin Sri Yan (ลูกชิ้นศรีย่าน)                  13.784805  100.512836
# Massage In Garden                                   13.762363  100.495126
# Tai Hong Kong Shrine (ศาลเจ้าไต้ฮงกง)               13.744578  100.510755
# Starbucks (สตาร์บัคส์)                              13.740937  100.495394
# Starbucks (สตาร์บัคส์)                              13.759789  100.486097
# ELF925                                              13.720542  100.499507
# Books Kinokuniya (คิโนะคูนิยะ)                      13.745839  100.534951
# สวนเฉลิมพระเกียรติ ๘๐ พรรษา พระบาทสมเด็จพระเจ้า...  13.772266  100.468441
# Mandarin Oriental, Bangkok                          13.723993  100.514241
# The Siam                                            13.781879  100.504775
# RBSC Fitness Club                                   13.739676  100.536097
# Hanazen (ฮานะเซน)                                   13.779563  100.538591
# Wat Pho Thai Traditional Medical and Massage Sc...  13.746596  100.494100
# Co van Kessel                                       13.730553  100.513835
# Wat Arun Prang (พระปรางค์วัดอรุณฯ)                  13.743696  100.488930
# Supanniga Eating Room x Roots Coffee (ห้องทานข้...  13.744162  100.491700
# Pai Spa (ปัยย์สปา บ้านรามบุตรี)                     13.759522  100.498694
# Ta Bun Tum (ตะบันตำ)                                13.779375  100.477465
# Gourmet Market (กูร์เมต์ มาร์เก็ต)                  13.746354  100.534550
# In a Box Hostel                                     13.755931  100.533678
# Tonkatsu Wako (หมูทอด วาโก)                         13.746509  100.531974
# Phya Thai Palace (พระราชวังพญาไท)                   13.768419  100.532756
# The Yard (บ้านญาติ โฮสเทล)                          13.776261  100.541744
# Rod Dee Det (รสดีเด็ด)                              13.734807  100.524340
# Mont Nom Sod (มนต์นมสด)                             13.751464  100.478605
# Siam Kempinski Hotel Bangkok                        13.748260  100.535074
# ...                                                       ...         ...
# Kenji's Lab                                         13.736770  100.584440
# Train Night Market Ratchada (ตลาดนัดรถไฟ รัชดา)     13.766791  100.568827
# Arunwan (อรุณวรรณ)                                  13.734906  100.587778
# Chaaloem Phrakiat Park (สวนสาธารณะเฉลิมพระเกียร...  13.685724  100.518524
# manycups                                            13.721023  100.569374
# ISAO (อิซาโอะ)                                      13.734558  100.566417
# The Oasis Spa                                       13.740833  100.568225
# ก๋วยเตี๋ยวเนื้อตุ๋นท่าน้ำสาธุฯ                      13.677993  100.527887
# Sühring                                             13.710749  100.545607
# Lookshin Anamai (ลูกชิ้น อนามัย)                    13.747697  100.583404
# Teppen (เท้ปเป้น)                                   13.722948  100.583401
# The Oyster Bar                                      13.701563  100.537315
# อุทยานเฉลิมกาญจนาภิเษก                              13.849820  100.481134
# Baan Somtum (บ้านส้มตำ)                             13.767756  100.395465
# Baan Somtum (บ้านส้มตำ)                             13.830266  100.480292
# Starbucks (สตาร์บัคส์)                              13.841061  100.533853
# OK Shabu Shabu                                      13.734662  100.577545
# Kaizen Coffee Newold                                13.740010  100.589747
# The Commons (เดอะคอมม่อนส์)                         13.735056  100.582229
# ก๋วยเตี๋ยวนายแว่น                                   13.734431  100.587621
# Starbucks (สตาร์บัคส์)                              13.844133  100.568736
# Octave Rooftop Lounge & Bar                         13.723549  100.580519
# Think Space B2S (ธิงค์สเปซ บีทูเอส)                 13.804555  100.614559
# After You (อาฟเตอร์ ยู)                             13.713528  100.408106
# Zong Ped Palow (ซ้งเป็ดพะโล้)                       13.830590  100.592429
# Pho' 54 (เฝอ 54)                                    13.822019  100.591708
# Ob Aroi (อบอร่อย)                                   13.771796  100.608878
# PHO'54 (เฝอ'54)                                     13.815520  100.596351
# Starbucks (สตาร์บัคส์)                              13.669379  100.451663
# Maria (มาเรีย)                                      13.867007  100.451483
#
#                                                       Category  Attraction  \
# Venue_Name
# Adhere the 13th Blues Bar                           Attraction           1
# Riva Surya Bangkok                                     Service           0
# Temple of the Emerald Buddha (วัดพระศรีรัตนศาสด...  Attraction           1
# Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตม...  Attraction           1
# Look Chin Sri Yan (ลูกชิ้นศรีย่าน)                        Food           0
# Massage In Garden                                      Service           0
# Tai Hong Kong Shrine (ศาลเจ้าไต้ฮงกง)               Attraction           1
# Starbucks (สตาร์บัคส์)                              Attraction           1
# Starbucks (สตาร์บัคส์)                              Attraction           1
# ELF925                                              Attraction           1
# Books Kinokuniya (คิโนะคูนิยะ)                      Attraction           1
# สวนเฉลิมพระเกียรติ ๘๐ พรรษา พระบาทสมเด็จพระเจ้า...  Attraction           1
# Mandarin Oriental, Bangkok                          Attraction           1
# The Siam                                               Service           0
# RBSC Fitness Club                                   Attraction           1
# Hanazen (ฮานะเซน)                                         Food           0
# Wat Pho Thai Traditional Medical and Massage Sc...     Service           0
# Co van Kessel                                       Attraction           1
# Wat Arun Prang (พระปรางค์วัดอรุณฯ)                  Attraction           1
# Supanniga Eating Room x Roots Coffee (ห้องทานข้...        Food           0
# Pai Spa (ปัยย์สปา บ้านรามบุตรี)                        Service           0
# Ta Bun Tum (ตะบันตำ)                                      Food           0
# Gourmet Market (กูร์เมต์ มาร์เก็ต)                  Attraction           1
# In a Box Hostel                                        Service           0
# Tonkatsu Wako (หมูทอด วาโก)                               Food           0
# Phya Thai Palace (พระราชวังพญาไท)                   Attraction           1
# The Yard (บ้านญาติ โฮสเทล)                             Service           0
# Rod Dee Det (รสดีเด็ด)                                    Food           0
# Mont Nom Sod (มนต์นมสด)                             Attraction           1
# Siam Kempinski Hotel Bangkok                           Service           0
# ...                                                        ...         ...
# Kenji's Lab                                               Food           0
# Train Night Market Ratchada (ตลาดนัดรถไฟ รัชดา)     Attraction           1
# Arunwan (อรุณวรรณ)                                        Food           0
# Chaaloem Phrakiat Park (สวนสาธารณะเฉลิมพระเกียร...  Attraction           1
# manycups                                            Attraction           1
# ISAO (อิซาโอะ)                                            Food           0
# The Oasis Spa                                          Service           0
# ก๋วยเตี๋ยวเนื้อตุ๋นท่าน้ำสาธุฯ                            Food           0
# Sühring                                                   Food           0
# Lookshin Anamai (ลูกชิ้น อนามัย)                          Food           0
# Teppen (เท้ปเป้น)                                         Food           0
# The Oyster Bar                                            Food           0
# อุทยานเฉลิมกาญจนาภิเษก                              Attraction           1
# Baan Somtum (บ้านส้มตำ)                                   Food           0
# Baan Somtum (บ้านส้มตำ)                                   Food           0
# Starbucks (สตาร์บัคส์)                              Attraction           1
# OK Shabu Shabu                                            Food           0
# Kaizen Coffee Newold                                Attraction           1
# The Commons (เดอะคอมม่อนส์)                         Attraction           1
# ก๋วยเตี๋ยวนายแว่น                                         Food           0
# Starbucks (สตาร์บัคส์)                              Attraction           1
# Octave Rooftop Lounge & Bar                               Food           0
# Think Space B2S (ธิงค์สเปซ บีทูเอส)                 Attraction           1
# After You (อาฟเตอร์ ยู)                             Attraction           1
# Zong Ped Palow (ซ้งเป็ดพะโล้)                             Food           0
# Pho' 54 (เฝอ 54)                                          Food           0
# Ob Aroi (อบอร่อย)                                         Food           0
# PHO'54 (เฝอ'54)                                           Food           0
# Starbucks (สตาร์บัคส์)                              Attraction           1
# Maria (มาเรีย)                                            Food           0
#
#                                                     Food  Service
# Venue_Name
# Adhere the 13th Blues Bar                              0        0
# Riva Surya Bangkok                                     0        1
# Temple of the Emerald Buddha (วัดพระศรีรัตนศาสด...     0        0
# Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตม...     0        0
# Look Chin Sri Yan (ลูกชิ้นศรีย่าน)                     1        0
# Massage In Garden                                      0        1
# Tai Hong Kong Shrine (ศาลเจ้าไต้ฮงกง)                  0        0
# Starbucks (สตาร์บัคส์)                                 0        0
# Starbucks (สตาร์บัคส์)                                 0        0
# ELF925                                                 0        0
# Books Kinokuniya (คิโนะคูนิยะ)                         0        0
# สวนเฉลิมพระเกียรติ ๘๐ พรรษา พระบาทสมเด็จพระเจ้า...     0        0
# Mandarin Oriental, Bangkok                             0        0
# The Siam                                               0        1
# RBSC Fitness Club                                      0        0
# Hanazen (ฮานะเซน)                                      1        0
# Wat Pho Thai Traditional Medical and Massage Sc...     0        1
# Co van Kessel                                          0        0
# Wat Arun Prang (พระปรางค์วัดอรุณฯ)                     0        0
# Supanniga Eating Room x Roots Coffee (ห้องทานข้...     1        0
# Pai Spa (ปัยย์สปา บ้านรามบุตรี)                        0        1
# Ta Bun Tum (ตะบันตำ)                                   1        0
# Gourmet Market (กูร์เมต์ มาร์เก็ต)                     0        0
# In a Box Hostel                                        0        1
# Tonkatsu Wako (หมูทอด วาโก)                            1        0
# Phya Thai Palace (พระราชวังพญาไท)                      0        0
# The Yard (บ้านญาติ โฮสเทล)                             0        1
# Rod Dee Det (รสดีเด็ด)                                 1        0
# Mont Nom Sod (มนต์นมสด)                                0        0
# Siam Kempinski Hotel Bangkok                           0        1
# ...                                                  ...      ...
# Kenji's Lab                                            1        0
# Train Night Market Ratchada (ตลาดนัดรถไฟ รัชดา)        0        0
# Arunwan (อรุณวรรณ)                                     1        0
# Chaaloem Phrakiat Park (สวนสาธารณะเฉลิมพระเกียร...     0        0
# manycups                                               0        0
# ISAO (อิซาโอะ)                                         1        0
# The Oasis Spa                                          0        1
# ก๋วยเตี๋ยวเนื้อตุ๋นท่าน้ำสาธุฯ                         1        0
# Sühring                                                1        0
# Lookshin Anamai (ลูกชิ้น อนามัย)                       1        0
# Teppen (เท้ปเป้น)                                      1        0
# The Oyster Bar                                         1        0
# อุทยานเฉลิมกาญจนาภิเษก                                 0        0
# Baan Somtum (บ้านส้มตำ)                                1        0
# Baan Somtum (บ้านส้มตำ)                                1        0
# Starbucks (สตาร์บัคส์)                                 0        0
# OK Shabu Shabu                                         1        0
# Kaizen Coffee Newold                                   0        0
# The Commons (เดอะคอมม่อนส์)                            0        0
# ก๋วยเตี๋ยวนายแว่น                                      1        0
# Starbucks (สตาร์บัคส์)                                 0        0
# Octave Rooftop Lounge & Bar                            1        0
# Think Space B2S (ธิงค์สเปซ บีทูเอส)                    0        0
# After You (อาฟเตอร์ ยู)                                0        0
# Zong Ped Palow (ซ้งเป็ดพะโล้)                          1        0
# Pho' 54 (เฝอ 54)                                       1        0
# Ob Aroi (อบอร่อย)                                      1        0
# PHO'54 (เฝอ'54)                                        1        0
# Starbucks (สตาร์บัคส์)                                 0        0
# Maria (มาเรีย)                                         1        0
#
# [119 rows x 6 columns]

# %%
# Creating map of Thailand.
map_bangkok = folium.Map(location=[latitude, longitude], zoom_start=9.5)

# add markers to map
for lat, lng, name in zip(df_final['Latitude'], df_final['Longitude'], df_final['Category']):
    folium.Marker(
        [lat, lng],
        popup=name,).add_to(map_bangkok)

# %%
# Running data through model to determine optimal K with all features.
k_clusters = list(range(1, 15))
inertia = []
for k in k_clusters:
    model = KMeans(n_clusters=k)
    model = model.fit(df_final.drop('Category', axis=1))
    inertia.append(model.inertia_)
    
plt.plot(k_clusters, inertia)

# %%
# Running data through model to determine optimal K with only latitude and longitude.
k_clusters = list(range(1, 15))
inertia = []
for k in k_clusters:
    model = KMeans(n_clusters=k)
    model = model.fit(df_final[['Latitude', 'Longitude']])
    inertia.append(model.inertia_)
    
plt.plot(k_clusters, inertia)

# %%
# Creating the final clusters.
model = KMeans(n_clusters=7)
model = model.fit(df_final[['Latitude', 'Longitude']])
clustered_group = df_final.copy()
clustered_group.insert(0, 'Cluster Labels', model.labels_)
clustered_group.head()
# Out:
#                                                     Cluster Labels   Latitude  \
# Venue_Name
# Adhere the 13th Blues Bar                                        5  13.763043
# Riva Surya Bangkok                                               5  13.762308
# Temple of the Emerald Buddha (วัดพระศรีรัตนศาสด...               5  13.751735
# Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตม...               5  13.750105
# Look Chin Sri Yan (ลูกชิ้นศรีย่าน)                               5  13.784805
#
#                                                      Longitude    Category  \
# Venue_Name
# Adhere the 13th Blues Bar                           100.498839  Attraction
# Riva Surya Bangkok                                  100.493020     Service
# Temple of the Emerald Buddha (วัดพระศรีรัตนศาสด...  100.492651  Attraction
# Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตม...  100.490524  Attraction
# Look Chin Sri Yan (ลูกชิ้นศรีย่าน)                  100.512836        Food
#
#                                                     Attraction  Food  Service
# Venue_Name
# Adhere the 13th Blues Bar                                    1     0        0
# Riva Surya Bangkok                                           0     0        1
# Temple of the Emerald Buddha (วัดพระศรีรัตนศาสด...           1     0        0
# Dusit Maha Prasat Throne Hall (พระที่นั่งดุสิตม...           1     0        0
# Look Chin Sri Yan (ลูกชิ้นศรีย่าน)                           0     1        0

# %%
# Creating map of Thailand.
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=9.5)

x = np.arange(7)
ys = [i + x + (i*x)**2 for i in range(7)]
colors_array = plt.cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to map
for lat, lng, name, label in zip(clustered_group['Latitude'], clustered_group['Longitude'], clustered_group['Category'], clustered_group['Cluster Labels']):
    folium.CircleMarker(
        location=[lat, lng],
        radius=5,
        color=rainbow[label-1],
        fill=True,
        fill_color=rainbow[label-1],
        fill_opacity=0.7).add_to(map_clusters)  

# add centroids to map
for lat, lang in model.cluster_centers_:
    folium.CircleMarker(
        location=[lat, lang],
        radius=5,
        color='black',
        fill=True,
        fill_color='black',
        fill_opacity=0.7).add_to(map_clusters)  

map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
# [13.71820846093777, 100.52075198884063]
# [13.73116525284773, 100.57308495715607]
# [13.815422008805333, 100.55915363857069]
# [13.833787852814021, 100.46888542129045]
# [13.748058562329687, 100.54058211790503]
# [13.76032674335472, 100.4908838649444]
# [13.733192139288361, 100.42171333289963]
